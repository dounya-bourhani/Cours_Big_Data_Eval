# %% [markdown]
# # Mongo tutorial

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### Documentation
#
# You will find all documentation for :
# * [Mongo commands](https://docs.mongodb.com/manual/reference/)
# * [Mongo python client](http://api.mongodb.com/python/current/api/pymongo/mongo_client.html#pymongo.mongo_client.MongoClient)

# %% [markdown]
# ### Import libraries

# %%
import datetime
from pprint import pprint

import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

# %%
# let's work in a test_database
db = client.test_database
posts = db.posts

# %%
post = {
    "author": "Mike",
    "text": "My first blog post!",
    "tags": ["mongodb", "python", "pymongo"],
    "date": datetime.datetime.utcnow()
}
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('65ae5d8a65925e6c68a9568b')

# %%
db.list_collection_names()
# Out:
# ['posts']

# %%
pprint(posts.find_one())
# Out:
# {'_id': ObjectId('65ae5d8a65925e6c68a9568b'),
#  'author': 'Mike',
#  'date': datetime.datetime(2024, 1, 22, 12, 20, 26, 317000),
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# You can launch a terminal aside, connect to your server with a mongo client and check that the value is present :
#
# ```bash
# vagrant@nosql:~$ mongo
# > show databases;
# admin          0.000GB
# config         0.000GB
# local          0.000GB
# test_database  0.000GB
# > use test_database;
# switched to db test_database
# > db.posts.find()
# {
#     "_id" : ObjectId("..."),
#     "author" : "Mike",
#     "text" : "My first blog post!",
#     "tags" : [ "mongodb", "python", "pymongo"],
#     "date" : ISODate("2019-02-10T11:33:47.883Z")
# }
# ```

# %% [markdown]
# ## I. Quick start

# %% [markdown]
# ### First steps

# %% [markdown]
# **Q** : Create a document `{msg: 'hello'}` in the `test` collection with `insert_one()`. Fetch it back to display it. What is the `_id` for ?
#
# NB : if the collection doesn't exist yet, MongoDB automatically creates it.

# %%
document = {'msg': 'hello'}

test_collection = db['test']

doc_inserted = test_collection.insert_one(document)

retrieved_doc = test_collection.find_one({'_id' : doc_inserted.inserted_id})

# %%
print(retrieved_doc)
# Out:
# {'_id': ObjectId('65ae611b65925e6c68a9568c'), 'msg': 'hello'}

# %% [markdown]
# **Q**: Display the number of documents inside the `test` collection

# %%
nb_doc = test_collection.count_documents({})
print(nb_doc)
# Out:
# 1

# %% [markdown]
# ### Interacting with a database
#
# We have 2 `.json` files we want to interact with inside the `data` folder. Let's first dump them into a `MovieLens` database, inside `users` and `movies` collections.
#
# For this section, you will need to read a bit on [query operators](https://docs.mongodb.com/manual/reference/operator/query/#query-selectors). Most methods on collections you will use have `filter` as a first parameter, on which you must pass a dictionary of query parameters.

# %% [markdown]
# **Q** : In the `MovieLens` database, load `data/movielens_movies.json` into `movies` and `data/movielens_users.json` into `users`.
#
# Use the dedicated shell command for this : `mongoimport --db <some_db> --collection <some_collection> --file <some_file>`

# %%
db = client.MovieLens
movies = db['collection_movies']
users = db['collection_users']

# %%
# !mongoimport --db MovieLens --collection collection_movies --file data/movielens_movies.json 
# !mongoimport --db MovieLens --collection collection_users --file data/movielens_users.json
# Out:
# 2024-01-22T13:46:09.288+0100	connected to: localhost
# 2024-01-22T13:46:09.460+0100	imported 3883 documents
# 2024-01-22T13:46:09.628+0100	connected to: localhost
# 2024-01-22T13:46:10.838+0100	imported 6040 documents

# %% [markdown]
# **Q** : how many users are in the `MovieLens` database ?

# %%
nb_users = users.count_documents({})
print(f"Nombre d'utilisateurs : {nb_users}")
# Out:
# Nombre d'utilisateurs : 6040

# %% [markdown]
# **Q** : Display all comedies (the `genres` property equals `Comedy`).
#
# NB : You will need to find how to go through a `command_cursor`, then use the `pprint` function for a better display of those documents.

# %%
comedy_movies = movies.find({"genres": "Comedy"})
for comedy_movie in comedy_movies:
    pprint(comedy_movie['title'])
# Out:
# 'Ace Ventura: When Nature Calls (1995)'
# 'Father of the Bride Part II (1995)'
# 'It Takes Two (1995)'
# ("Don't Be a Menace to South Central While Drinking Your Juice in the Hood "
#  '(1996)')
# 'Bio-Dome (1996)'
# 'Friday (1995)'
# 'Mighty Aphrodite (1995)'
# 'Black Sheep (1996)'
# 'In the Bleak Midwinter (1995)'
# 'Bottle Rocket (1996)'
# 'Mr. Wrong (1996)'
# 'Happiness Is in the Field (1995)'
# 'Steal Big, Steal Little (1995)'
# 'Flirting With Disaster (1996)'
# 'Happy Gilmore (1996)'
# 'Down Periscope (1996)'
# 'Headless Body in Topless Bar (1995)'
# 'Birdcage, The (1996)'
# 'Brothers McMullen, The (1995)'
# 'Blue in the Face (1995)'
# 'Jury Duty (1995)'
# 'Living in Oblivion (1995)'
# 'Mallrats (1995)'
# 'Love & Human Remains (1993)'
# 'Nine Months (1995)'
# 'Party Girl (1995)'
# 'Reckless (1995)'
# 'Jeffrey (1995)'
# 'To Wong Foo, Thanks for Everything! Julie Newmar (1995)'
# 'Bushwhacked (1995)'
# 'Billy Madison (1995)'
# 'Clerks (1994)'
# 'Destiny Turns on the Radio (1995)'
# 'Dumb & Dumber (1994)'
# 'Exit to Eden (1994)'
# 'Gordy (1995)'
# 'Houseguest (1994)'
# 'Major Payne (1994)'
# 'Man of the House (1995)'
# 'Mixed Nuts (1994)'
# 'Miami Rhapsody (1995)'
# 'Jerky Boys, The (1994)'
# 'Pushing Hands (1992)'
# 'Ready to Wear (Pret-A-Porter) (1994)'
# 'Rent-a-Kid (1995)'
# 'Stuart Saves His Family (1995)'
# 'Tommy Boy (1995)'
# 'Ace Ventura: Pet Detective (1994)'
# 'Bullets Over Broadway (1994)'
# 'Crooklyn (1994)'
# 'Sum of Us, The (1994)'
# "National Lampoon's Senior Trip (1995)"
# 'Naked Gun 33 1/3: The Final Insult (1994)'
# 'Addams Family Values (1993)'
# 'You So Crazy (1994)'
# 'Air Up There, The (1994)'
# 'Beverly Hillbillies, The (1993)'
# 'Cabin Boy (1994)'
# 'Airheads (1994)'
# 'Open Season (1996)'
# 'Clean Slate (1994)'
# 'Cops and Robbersons (1994)'
# 'Dazed and Confused (1993)'
# 'Fatal Instinct (1993)'
# 'Fear of a Black Hat (1993)'
# 'For Love or Money (1993)'
# 'Getting Even with Dad (1994)'
# 'Live Nude Girls (1995)'
# 'House Party 3 (1994)'
# 'Made in America (1993)'
# 'Mrs. Doubtfire (1993)'
# 'North (1994)'
# 'Life with Mikey (1993)'
# 'Ref, The (1994)'
# 'Road to Wellville, The (1994)'
# 'Robin Hood: Men in Tights (1993)'
# 'Jimmy Hollywood (1994)'
# 'Son in Law (1993)'
# 'Paris, France (1993)'
# 'Chasers (1994)'
# 'Fausto (1993)'
# 'Metisse (Caf� au Lait) (1993)'
# 'Brady Bunch Movie, The (1995)'
# 'Window to Paris (1994)'
# 'Bye Bye, Love (1995)'
# 'Pallbearer, The (1996)'
# 'Ed (1996)'
# 'Thin Line Between Love and Hate, A (1996)'
# 'Denise Calls Up (1995)'
# 'Theodore Rex (1995)'
# 'Sgt. Bilko (1996)'
# 'Girl 6 (1996)'
# 'Little Indian, Big City (Un indien dans la ville) (1994)'
# 'Peanuts - Die Bank zahlt alles (1996)'
# 'Happy Weekend (1996)'
# 'Superweib, Das (1996)'
# 'Eddie (1996)'
# 'Mutters Courage (1995)'
# 'Kids in the Hall: Brain Candy (1996)'
# 'Faithful (1996)'
# 'Cosi (1996)'
# 'Angus (1995)'
# 'Mouth to Mouth (Boca a boca) (1995)'
# 'Multiplicity (1996)'
# 'Great White Hype, The (1996)'
# 'Celtic Pride (1996)'
# 'Honigmond (1996)'
# 'Spy Hard (1996)'
# 'Stupids, The (1996)'
# 'Careful (1992)'
# 'Cold Comfort Farm (1995)'
# 'Getting Away With Murder (1996)'
# 'Quartier Mozart (1992)'
# 'Cable Guy, The (1996)'
# 'Kingpin (1996)'
# ('Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) '
#  '(1991)')
# 'Bewegte Mann, Der (1994)'
# 'Larger Than Life (1996)'
# 'Very Brady Sequel, A (1996)'
# 'First Wives Club, The (1996)'
# 'High School High (1996)'
# 'Phat Beach (1996)'
# 'House Arrest (1996)'
# 'Mille bolle blu (1993)'
# 'Maybe, Maybe Not (Bewegte Mann, Der) (1994)'
# 'Celestial Clockwork (1994)'
# 'Death in Brunswick (1991)'
# "Lover's Knot (1996)"
# "Gone Fishin' (1997)"
# 'It Happened One Night (1934)'
# 'Women, The (1939)'
# 'Father of the Bride (1950)'
# 'My Favorite Year (1982)'
# 'My Man Godfrey (1936)'
# 'His Girl Friday (1940)'
# 'Bringing Up Baby (1938)'
# "Ed's Next Move (1996)"
# "Associate, The (L'Associe)(1982)"
# 'Cool Runnings (1993)'
# 'That Thing You Do! (1996)'
# 'Sexual Life of the Belgians, The (1994)'
# 'Fish Called Wanda, A (1988)'
# "Monty Python's Life of Brian (1979)"
# "Weekend at Bernie's (1989)"
# 'Search for One-eye Jimmy, The (1996)'
# 'Loser (1991)'
# 'Return of the Pink Panther, The (1974)'
# 'Associate, The (1996)'
# 'Private Benjamin (1980)'
# 'Monty Python and the Holy Grail (1974)'
# 'Three Lives and Only One Death (1996)'
# 'Here Comes Cookie (1935)'
# 'Six of a Kind (1934)'
# 'Ruling Class, The (1972)'
# 'Hear My Song (1991)'
# 'Dear God (1996)'
# 'Bob Roberts (1992)'
# 'Farmer & Chase (1995)'
# 'Up in Smoke (1978)'
# 'Grosse Fatigue (1994)'
# 'Withnail and I (1987)'
# 'Harold and Maude (1971)'
# 'Local Hero (1983)'
# 'Better Off Dead... (1985)'
# 'Great Dictator, The (1940)'
# 'Heathers (1989)'
# 'Being There (1979)'
# 'I Shot a Man in Vegas (1995)'
# 'Santa with Muscles (1996)'
# 'Real Genius (1985)'
# "I'm Not Rappaport (1996)"
# 'My Fellow Americans (1996)'
# 'Raising Arizona (1987)'
# 'Mother (1996)'
# 'Fierce Creatures (1997)'
# 'Falling in Love Again (1980)'
# 'Amos & Andrew (1993)'
# 'Meet Wally Sparks (1997)'
# 'Guantanamera (1994)'
# 'Kolya (1996)'
# 'Waiting for Guffman (1996)'
# 'SubUrbia (1997)'
# 'Pest, The (1997)'
# 'Vegas Vacation (1997)'
# 'B*A*P*S (1997)'
# 'Liar Liar (1997)'
# 'Sixth Man, The (1997)'
# 'Children of the Revolution (1996)'
# 'Austin Powers: International Man of Mystery (1997)'
# "Fathers' Day (1997)"
# 'Intimate Relations (1996)'
# 'Sprung (1997)'
# '8 Heads in a Duffel Bag (1997)'
# 'Shall We Dance? (Shall We Dansu?) (1996)'
# 'Schizopolis (1996)'
# 'A Chef in Love (1996)'
# "Romy and Michele's High School Reunion (1997)"
# 'Sudden Manhattan (1996)'
# 'Late Bloomers (1996)'
# 'Wedding Bell Blues (1996)'
# 'Out to Sea (1997)'
# 'Love Serenade (1996)'
# 'Leave It to Beaver (1997)'
# 'Kiss Me, Guido (1997)'
# 'Full Monty, The (1997)'
# 'Rocket Man (1997)'
# 'How to Be a Player (1997)'
# 'In & Out (1997)'
# 'Stripes (1981)'
# 'Bean (1997)'
# 'Critical Care (1997)'
# 'Chairman of the Board (1998)'
# 'Boys, Les (1997)'
# 'For Richer or Poorer (1997)'
# 'Mr. Magoo (1997)'
# 'Vermin (1998)'
# 'Senseless (1998)'
# 'Half Baked (1998)'
# 'Welcome to Woop-Woop (1997)'
# 'Follow the Bitch (1998)'
# 'Odd Couple II, The (1998)'
# 'My Giant (1998)'
# 'Alan Smithee Film: Burn Hollywood Burn, An (1997)'
# 'Clockwatchers (1997)'
# 'Sour Grapes (1998)'
# "Krippendorf's Tribe (1998)"
# 'Real Blonde, The (1997)'
# 'Major League: Back to the Minors (1998)'
# 'Bulworth (1998)'
# 'I Got the Hook Up (1998)'
# 'Cousin Bette (1998)'
# 'Doctor Dolittle (1998)'
# "There's Something About Mary (1998)"
# 'Hav Plenty (1997)'
# "You Can't Take It With You (1938)"
# 'Going My Way (1944)'
# 'Tom Jones (1963)'
# 'Take the Money and Run (1969)'
# 'Metropolitan (1990)'
# 'Polish Wedding (1998)'
# 'BASEketball (1998)'
# 'Devil and Max Devlin, The (1981)'
# "'burbs, The (1989)"
# 'Fandango (1985)'
# 'Jerk, The (1979)'
# 'Addams Family, The (1991)'
# 'Safe Men (1998)'
# 'Man with Two Brains, The (1983)'
# 'Weird Science (1985)'
# 'Nutty Professor, The (1963)'
# 'Sixteen Candles (1984)'
# 'Gods Must Be Crazy, The (1980)'
# 'Gods Must Be Crazy II, The (1989)'
# 'Slums of Beverly Hills, The (1998)'
# 'Dead Man on Campus (1998)'
# 'Strike! (a.k.a. All I Wanna Do, The Hairy Bird) (1998)'
# 'Merry War, A (1997)'
# 'Dirty Work (1998)'
# 'Mr. & Mrs. Smith (1941)'
# "Farmer's Wife, The (1928)"
# 'Always Tell Your Wife (1923)'
# 'Champagne (1928)'
# 'Stars and Bars (1988)'
# 'Married to the Mob (1988)'
# 'My Blue Heaven (1990)'
# 'Young Doctors in Love (1982)'
# 'Cabinet of Dr. Ramirez, The (1991)'
# 'One Crazy Summer (1986)'
# 'Class (1983)'
# 'Fiendish Plot of Dr. Fu Manchu, The (1980)'
# 'Impostors, The (1998)'
# 'Night at the Roxbury, A (1998)'
# 'Battle of the Sexes, The (1959)'
# 'History of the World: Part I (1981)'
# 'My Cousin Vinny (1992)'
# 'Holy Man (1998)'
# 'Alarmist, The (1997)'
# 'Happiness (1998)'
# 'Reach the Rock (1997)'
# 'Pleasantville (1998)'
# 'Orgazmo (1997)'
# 'Waterboy, The (1998)'
# 'Hard Core Logo (1996)'
# 'Heart Condition (1990)'
# 'Celebrity (1998)'
# 'Pink Flamingos (1972)'
# 'Waking Ned Devine (1998)'
# 'Fletch Lives (1989)'
# 'Fletch (1985)'
# 'Money Pit, The (1986)'
# 'Police Academy (1984)'
# 'Police Academy 3: Back in Training (1986)'
# 'Police Academy 4: Citizens on Patrol (1987)'
# 'Police Academy 2: Their First Assignment (1985)'
# 'Police Academy 5: Assignment: Miami Beach (1988)'
# 'Police Academy 6: City Under Siege (1989)'
# 'Little Voice (1998)'
# 'Rushmore (1998)'
# 'Back to School (1986)'
# 'Nothing in Common (1986)'
# 'Christmas Vacation (1989)'
# 'Tea with Mussolini (1999)'
# 'Ruthless People (1986)'
# 'Tough Guys (1986)'
# 'Soul Man (1986)'
# 'Tinseltown (1998)'
# 'Jawbreaker (1999)'
# "God Said 'Ha!' (1998)"
# '20 Dates (1998)'
# 'Breakfast of Champions (1999)'
# 'Eight Days a Week (1997)'
# 'Night Shift (1982)'
# 'Analyze This (1999)'
# "My Boyfriend's Back (1993)"
# 'Baby Geniuses (1999)'
# "Relax... It's Just Sex (1998)"
# 'EDtv (1999)'
# 'Six Ways to Sunday (1997)'
# 'Out-of-Towners, The (1999)'
# 'Foolish (1999)'
# 'Life (1999)'
# 'Monster, The (Il Mostro) (1994)'
# 'Pushing Tin (1999)'
# 'Little Bit of Soul, A (1998)'
# 'Election (1999)'
# 'Castle, The (1997)'
# "Trippin' (1999)"
# 'Austin Powers: The Spy Who Shagged Me (1999)'
# 'Ideal Husband, An (1999)'
# 'American Pie (1999)'
# 'Dinner Game, The (Le D�ner de cons) (1998)'
# 'Drop Dead Gorgeous (1999)'
# 'Big Daddy (1999)'
# 'Brighton Beach Memoirs (1986)'
# 'Dick (1999)'
# 'Illuminata (1998)'
# 'Stiff Upper Lips (1998)'
# 'Bowfinger (1999)'
# 'Detroit Rock City (1999)'
# 'From the Hip (1987)'
# 'Heaven Can Wait (1978)'
# 'Haunted Honeymoon (1986)'
# 'And Now for Something Completely Different (1971)'
# 'Airplane! (1980)'
# 'Airplane II: The Sequel (1982)'
# 'European Vacation (1985)'
# 'Vacation (1983)'
# 'Problem Child 2 (1991)'
# 'Funny Farm (1988)'
# 'Problem Child (1990)'
# 'With Friends Like These... (1998)'
# 'Love Stinks (1999)'
# 'Outside Providence (1999)'
# 'I Woke Up Early the Day I Died (1998)'
# 'Blue Streak (1999)'
# 'Splendor (1999)'
# 'Sugar Town (1999)'
# 'Barefoot in the Park (1967)'
# 'Pajama Game, The (1957)'
# 'Mumford (1999)'
# 'Mystery, Alaska (1999)'
# 'Happy, Texas (1999)'
# 'Superstar (1999)'
# 'Risky Business (1983)'
# 'Mating Habits of the Earthbound Human, The (1998)'
# "Ferris Bueller's Day Off (1986)"
# "Citizen's Band (a.k.a. Handle with Care) (1977)"
# "Sullivan's Travels (1942)"
# 'Palm Beach Story, The (1942)'
# 'Crimes and Misdemeanors (1989)'
# 'Battling Butler (1926)'
# "Bustin' Loose (1981)"
# 'General, The (1927)'
# 'Taming of the Shrew, The (1967)'
# 'Repossessed (1990)'
# 'Man of the Century (1999)'
# 'Being John Malkovich (1999)'
# 'Trading Places (1983)'
# 'Meatballs 4 (1992)'
# 'Meatballs Part II (1984)'
# 'Meatballs (1979)'
# 'Meatballs III (1987)'
# "Where's Marlowe? (1999)"
# 'Under the Rainbow (1981)'
# 'Dogma (1999)'
# 'Moonstruck (1987)'
# 'March of the Wooden Soldiers (a.k.a. Laurel & Hardy in Toyland) (1934)'
# 'Scrooged (1988)'
# 'Harvey (1950)'
# 'Irma la Douce (1963)'
# 'My Man Godfrey (1957)'
# 'Distinguished Gentleman, The (1992)'
# 'Spring Fever USA (a.k.a. Lauderdale) (1989)'
# 'Broadway Damage (1997)'
# 'Go West (1925)'
# 'Daddy Long Legs (1919)'
# 'Bonfire of the Vanities (1990)'
# 'Three Ages, The (1923)'
# 'Deuce Bigalow: Male Gigolo (1999)'
# 'Next Friday (1999)'
# 'My Dog Skip (1999)'
# 'Fast Times at Ridgemont High (1982)'
# 'Wirey Spindell (1999)'
# 'Saphead, The (1920)'
# 'Seven Chances (1925)'
# 'Smashing Time (1967)'
# 'Train Ride to Hollywood (1978)'
# 'Where the Buffalo Roam (1980)'
# "Isn't She Great? (2000)"
# 'Cup, The (Ph�rpa) (1999)'
# 'Santitos (1997)'
# 'Encino Man (1992)'
# 'Big Tease, The (1999)'
# 'Sister Act 2: Back in the Habit (1993)'
# "White Men Can't Jump (1992)"
# "Wayne's World 2 (1993)"
# "Wayne's World (1992)"
# 'Gun Shy (2000)'
# 'Death Becomes Her (1992)'
# 'Different for Girls (1996)'
# 'Snow Day (2000)'
# 'Soft Toilet Seats (1999)'
# 'Beautiful People (1999)'
# 'Circus, The (1928)'
# '3 Strikes (2000)'
# 'Waiting Game, The (2000)'
# 'Drowning Mona (2000)'
# 'Class Reunion (1982)'
# "Dog's Life, A (1920)"
# 'Born Yesterday (1950)'
# 'Perils of Pauline, The (1947)'
# 'Bull Durham (1988)'
# 'Volunteers (1985)'
# "Who's Harry Crumb? (1989)"
# 'Harry and the Hendersons (1987)'
# 'She-Devil (1989)'
# 'Nadine (1987)'
# "Who's That Girl? (1987)"
# 'Animal House (1978)'
# 'Funny Bones (1995)'
# 'Grumpy Old Men (1993)'
# 'Hillbillys in a Haunted House (1967)'
# 'Modern Times (1936)'
# 'Last Resort (1994)'
# 'Jonah Who Will Be 25 in the Year 2000 (1976)'
# 'High Fidelity (2000)'
# 'My Chauffeur (1986)'
# 'Max Dugan Returns (1983)'
# 'Odd Couple, The (1968)'
# 'Ready to Rumble (2000)'
# 'Me Myself I (2000)'
# 'How to Stuff a Wild Bikini (1965)'
# 'Bachelor Party (1984)'
# 'Freedom for Us (� nous la libert� ) (1931)'
# 'Smoking/No Smoking (1993)'
# '28 Days (2000)'
# 'East is East (1999)'
# 'Shakes the Clown (1991)'
# 'Caddyshack (1980)'
# 'Bossa Nova (1999)'
# 'Lords of Flatbush, The (1974)'
# 'Held Up (2000)'
# 'Screwed (2000)'
# 'Whipped (2000)'
# 'Gay Deceivers, The (1969)'
# "Pee-wee's Big Adventure (1985)"
# 'Things Change (1988)'
# 'Road Trip (2000)'
# 'Small Time Crooks (2000)'
# 'Hollywood Knights, The (1980)'
# 'Twelve Chairs, The (1970)'
# '8 1/2 Women (1999)'
# 'Gold Rush, The (1925)'
# "It's in the Water (1998)"
# 'Monsieur Verdoux (1947)'
# "Big Momma's House (2000)"
# 'Stay Tuned (1992)'
# "Porky's II: The Next Day (1983)"
# "Porky's (1981)"
# "Porky's Revenge (1985)"
# 'Private School (1983)'
# 'Burglar (1987)'
# 'Soapdish (1991)'
# 'Trixie (1999)'
# 'Live Virgin (1999)'
# 'Me, Myself and Irene (2000)'
# 'Kentucky Fried Movie, The (1977)'
# 'House Party (1990)'
# 'House Party 2 (1991)'
# 'Kid, The (2000)'
# "But I'm a Cheerleader (1999)"
# 'Shower (Xizhao) (1999)'
# 'H.O.T.S. (1979)'
# 'Tampopo (1986)'
# 'Nutty Professor II: The Klumps (2000)'
# 'Better Living (1998)'
# 'Saving Grace (2000)'
# 'What About Bob? (1991)'
# 'Everything You Always Wanted to Know About Sex (1972)'
# 'Love and Death (1975)'
# 'Easy Money (1983)'
# 'Tao of Steve, The (2000)'
# "I'm the One That I Want (2000)"
# 'Cecil B. Demented (2000)'
# 'About Adam (2000)'
# 'Replacements, The (2000)'
# 'Bring It On (2000)'
# 'Naked Gun 2 1/2: The Smell of Fear, The (1991)'
# 'Sunset Strip (2000)'
# 'Crew, The (2000)'
# 'Naked Gun: From the Files of Police Squad!, The (1988)'
# 'Circus (2000)'
# 'Specials, The (2000)'
# 'Bikini Beach (1964)'
# 'Pajama Party (1964)'
# 'Beach Party (1963)'
# 'Stranger Than Paradise (1984)'
# 'Bank Dick, The (1940)'
# 'Best in Show (2000)'
# 'Meet the Parents (2000)'
# 'Bamboozled (2000)'

# %% [markdown]
# **Q** : Fetch and display the `name` and `occupation` for Clifford Johnathan. The second paramater for `find()` ([doc here](https://api.mongodb.com/python/current/api/pymongo/collection.html#pymongo.collection.Collection.find)) is called the `projection` and is used to limit which data to fetch from the query.

# %%
clifford = users.find({"name": "Clifford Johnathan"})
pprint(f"Name : {clifford[0]['name']}, Occupation : {clifford[0]['occupation']}")
# Out:
# 'Name : Clifford Johnathan, Occupation : technician/engineer'

# %% [markdown]
# **Q**: How many minors (by `age`) have rated movies ?

# %%
minors_count = users.count_documents({"age": {"$lt": 18}})
print(minors_count)
# Out:
# 222

# %% [markdown]
# **Q**: Display science fiction movies ('Sci-Fi') and suspense movies ('Thriller'). This time you need to use a regex to parse genres and look for those values.

# %%
# Define the regex pattern for genres
genres_regex = "Sci-Fi|Thriller"

# Find movies where the 'genres' property matches the regex pattern
science_fiction_and_suspense_movies = movies.find({"genres": {"$regex": genres_regex}})

# Display the results
for movie in science_fiction_and_suspense_movies:
    pprint(movie)
# Out:
# {'_id': 16, 'genres': 'Drama|Thriller', 'title': 'Casino (1995)'}
# {'_id': 18, 'genres': 'Thriller', 'title': 'Four Rooms (1995)'}
# {'_id': 22, 'genres': 'Crime|Drama|Thriller', 'title': 'Copycat (1995)'}
# {'_id': 23, 'genres': 'Thriller', 'title': 'Assassins (1995)'}
# {'_id': 24, 'genres': 'Drama|Sci-Fi', 'title': 'Powder (1995)'}
# {'_id': 29,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'City of Lost Children, The (1995)'}
# {'_id': 6, 'genres': 'Action|Crime|Thriller', 'title': 'Heat (1995)'}
# {'_id': 10, 'genres': 'Action|Adventure|Thriller', 'title': 'GoldenEye (1995)'}
# {'_id': 32, 'genres': 'Drama|Sci-Fi', 'title': 'Twelve Monkeys (1995)'}
# {'_id': 47, 'genres': 'Crime|Thriller', 'title': 'Seven (Se7en) (1995)'}
# {'_id': 51, 'genres': 'Action|Drama|Thriller', 'title': 'Guardian Angel (1994)'}
# {'_id': 66,
#  'genres': 'Sci-Fi|Thriller',
#  'title': 'Lawnmower Man 2: Beyond Cyberspace (1996)'}
# {'_id': 50, 'genres': 'Crime|Thriller', 'title': 'Usual Suspects, The (1995)'}
# {'_id': 61, 'genres': 'Drama|Thriller', 'title': 'Eye for an Eye (1996)'}
# {'_id': 70,
#  'genres': 'Action|Comedy|Crime|Horror|Thriller',
#  'title': 'From Dusk Till Dawn (1996)'}
# {'_id': 76, 'genres': 'Sci-Fi|Thriller', 'title': 'Screamers (1995)'}
# {'_id': 79, 'genres': 'Drama|Thriller', 'title': 'Juror, The (1996)'}
# {'_id': 89, 'genres': 'Action|Thriller', 'title': 'Nick of Time (1995)'}
# {'_id': 92, 'genres': 'Drama|Thriller', 'title': 'Mary Reilly (1996)'}
# {'_id': 98, 'genres': 'Action|Thriller', 'title': 'Shopping (1994)'}
# {'_id': 100, 'genres': 'Drama|Thriller', 'title': 'City Hall (1996)'}
# {'_id': 103, 'genres': 'Thriller', 'title': 'Unforgettable (1996)'}
# {'_id': 95, 'genres': 'Action|Thriller', 'title': 'Broken Arrow (1996)'}
# {'_id': 111, 'genres': 'Drama|Thriller', 'title': 'Taxi Driver (1976)'}
# {'_id': 132, 'genres': 'Thriller', 'title': 'Jade (1995)'}
# {'_id': 149, 'genres': 'Crime|Drama|Thriller', 'title': 'Amateur (1994)'}
# {'_id': 160,
#  'genres': 'Action|Adventure|Mystery|Sci-Fi',
#  'title': 'Congo (1995)'}
# {'_id': 164,
#  'genres': 'Crime|Film-Noir|Mystery|Thriller',
#  'title': 'Devil in a Blue Dress (1995)'}
# {'_id': 172,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Johnny Mnemonic (1995)'}
# {'_id': 173, 'genres': 'Action|Adventure|Sci-Fi', 'title': 'Judge Dredd (1995)'}
# {'_id': 183, 'genres': 'Thriller', 'title': 'Mute Witness (1994)'}
# {'_id': 185, 'genres': 'Sci-Fi|Thriller', 'title': 'Net, The (1995)'}
# {'_id': 161, 'genres': 'Drama|Thriller|War', 'title': 'Crimson Tide (1995)'}
# {'_id': 165,
#  'genres': 'Action|Thriller',
#  'title': 'Die Hard: With a Vengeance (1995)'}
# {'_id': 170, 'genres': 'Action|Crime|Thriller', 'title': 'Hackers (1995)'}
# {'_id': 190, 'genres': 'Thriller', 'title': 'Safe (1995)'}
# {'_id': 163, 'genres': 'Action|Romance|Thriller', 'title': 'Desperado (1995)'}
# {'_id': 196, 'genres': 'Horror|Sci-Fi', 'title': 'Species (1995)'}
# {'_id': 198, 'genres': 'Action|Crime|Sci-Fi', 'title': 'Strange Days (1995)'}
# {'_id': 200, 'genres': 'Thriller', 'title': 'Tie That Binds, The (1995)'}
# {'_id': 217, 'genres': 'Drama|Thriller', 'title': 'Babysitter, The (1995)'}
# {'_id': 226, 'genres': 'Thriller', 'title': 'Dream Man (1995)'}
# {'_id': 225, 'genres': 'Drama|Thriller', 'title': 'Disclosure (1994)'}
# {'_id': 229, 'genres': 'Drama|Thriller', 'title': 'Death and the Maiden (1994)'}
# {'_id': 230, 'genres': 'Drama|Thriller', 'title': 'Dolores Claiborne (1994)'}
# {'_id': 240, 'genres': 'Thriller', 'title': 'Hideaway (1995)'}
# {'_id': 247,
#  'genres': 'Drama|Fantasy|Romance|Thriller',
#  'title': 'Heavenly Creatures (1994)'}
# {'_id': 257, 'genres': 'Mystery|Thriller', 'title': 'Just Cause (1995)'}
# {'_id': 259, 'genres': 'Crime|Drama|Thriller', 'title': 'Kiss of Death (1995)'}
# {'_id': 256, 'genres': 'Comedy|Sci-Fi', 'title': 'Junior (1994)'}
# {'_id': 280, 'genres': 'Drama|Thriller', 'title': 'Murder in the First (1995)'}
# {'_id': 260,
#  'genres': 'Action|Adventure|Fantasy|Sci-Fi',
#  'title': 'Star Wars: Episode IV - A New Hope (1977)'}
# {'_id': 286,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Nemesis 2: Nebula (1995)'}
# {'_id': 288,
#  'genres': 'Action|Thriller',
#  'title': 'Natural Born Killers (1994)'}
# {'_id': 291, 'genres': 'Thriller', 'title': 'Poison Ivy II (1995)'}
# {'_id': 292, 'genres': 'Action|Drama|Thriller', 'title': 'Outbreak (1995)'}
# {'_id': 293,
#  'genres': 'Crime|Drama|Romance|Thriller',
#  'title': 'Professional, The (a.k.a. Leon: The Professional) (1994)'}
# {'_id': 311, 'genres': 'Horror|Thriller', 'title': 'Relative Fear (1994)'}
# {'_id': 316, 'genres': 'Action|Adventure|Sci-Fi', 'title': 'Stargate (1994)'}
# {'_id': 332, 'genres': 'Horror|Sci-Fi', 'title': 'Village of the Damned (1995)'}
# {'_id': 335, 'genres': 'Mystery|Thriller', 'title': 'Underneath, The (1995)'}
# {'_id': 338, 'genres': 'Sci-Fi|Thriller', 'title': 'Virtuosity (1995)'}
# {'_id': 319, 'genres': 'Thriller', 'title': 'Shallow Grave (1994)'}
# {'_id': 320, 'genres': 'Film-Noir|Thriller', 'title': 'Suture (1993)'}
# {'_id': 350, 'genres': 'Drama|Mystery|Thriller', 'title': 'Client, The (1994)'}
# {'_id': 349,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Clear and Present Danger (1994)'}
# {'_id': 353, 'genres': 'Action|Romance|Thriller', 'title': 'Crow, The (1994)'}
# {'_id': 327,
#  'genres': 'Action|Comedy|Musical|Sci-Fi',
#  'title': 'Tank Girl (1995)'}
# {'_id': 329,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: Generations (1994)'}
# {'_id': 373, 'genres': 'Thriller', 'title': 'Red Rock West (1992)'}
# {'_id': 376, 'genres': 'Action|Thriller', 'title': 'River Wild, The (1994)'}
# {'_id': 377, 'genres': 'Action|Romance|Thriller', 'title': 'Speed (1994)'}
# {'_id': 379, 'genres': 'Action|Sci-Fi', 'title': 'Timecop (1994)'}
# {'_id': 401, 'genres': 'Action|Thriller', 'title': 'Mirage (1995)'}
# {'_id': 405,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Highlander III: The Sorcerer (1994)'}
# {'_id': 407,
#  'genres': 'Horror|Thriller',
#  'title': 'In the Mouth of Madness (1995)'}
# {'_id': 415, 'genres': 'Comedy|Thriller', 'title': 'Another Stakeout (1993)'}
# {'_id': 422, 'genres': 'Thriller', 'title': 'Blink (1994)'}
# {'_id': 423, 'genres': 'Action|Thriller', 'title': 'Blown Away (1994)'}
# {'_id': 426,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Body Snatchers (1993)'}
# {'_id': 427,
#  'genres': 'Mystery|Romance|Thriller',
#  'title': 'Boxing Helena (1993)'}
# {'_id': 435, 'genres': 'Comedy|Sci-Fi', 'title': 'Coneheads (1993)'}
# {'_id': 436, 'genres': 'Drama|Thriller', 'title': 'Color of Night (1994)'}
# {'_id': 442, 'genres': 'Action|Sci-Fi', 'title': 'Demolition Man (1993)'}
# {'_id': 457, 'genres': 'Action|Thriller', 'title': 'Fugitive, The (1993)'}
# {'_id': 454, 'genres': 'Drama|Thriller', 'title': 'Firm, The (1993)'}
# {'_id': 463, 'genres': 'Crime|Drama|Thriller', 'title': 'Guilty as Sin (1993)'}
# {'_id': 464,
#  'genres': 'Action|Adventure|Crime|Thriller',
#  'title': 'Hard Target (1993)'}
# {'_id': 474, 'genres': 'Action|Thriller', 'title': 'In the Line of Fire (1993)'}
# {'_id': 482, 'genres': 'Thriller', 'title': 'Killing Zoe (1994)'}
# {'_id': 490, 'genres': 'Thriller', 'title': 'Malice (1993)'}
# {'_id': 494, 'genres': 'Action|Thriller', 'title': 'Executive Decision (1996)'}
# {'_id': 504, 'genres': 'Action|Sci-Fi', 'title': 'No Escape (1994)'}
# {'_id': 480,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Jurassic Park (1993)'}
# {'_id': 481, 'genres': 'Drama|Thriller', 'title': 'Kalifornia (1993)'}
# {'_id': 512,
#  'genres': 'Horror|Sci-Fi',
#  'title': "Robert A. Heinlein's The Puppet Masters (1994)"}
# {'_id': 519, 'genres': 'Sci-Fi|Thriller', 'title': 'Robocop 3 (1993)'}
# {'_id': 521, 'genres': 'Crime|Thriller', 'title': 'Romeo Is Bleeding (1993)'}
# {'_id': 540, 'genres': 'Thriller', 'title': 'Sliver (1993)'}
# {'_id': 541, 'genres': 'Film-Noir|Sci-Fi', 'title': 'Blade Runner (1982)'}
# {'_id': 547,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Surviving the Game (1994)'}
# {'_id': 554, 'genres': 'Thriller', 'title': 'Trial by Jury (1994)'}
# {'_id': 561, 'genres': 'Thriller', 'title': 'Killer (Bulletproof Heart) (1994)'}
# {'_id': 543,
#  'genres': 'Comedy|Romance|Thriller',
#  'title': 'So I Married an Axe Murderer (1993)'}
# {'_id': 579, 'genres': 'Thriller', 'title': 'Scorta, La (1993)'}
# {'_id': 587, 'genres': 'Comedy|Romance|Thriller', 'title': 'Ghost (1990)'}
# {'_id': 600, 'genres': 'Thriller', 'title': 'Love and a .45 (1994)'}
# {'_id': 608, 'genres': 'Crime|Drama|Thriller', 'title': 'Fargo (1996)'}
# {'_id': 589,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Terminator 2: Judgment Day (1991)'}
# {'_id': 546,
#  'genres': "Action|Adventure|Children's|Sci-Fi",
#  'title': 'Super Mario Bros. (1993)'}
# {'_id': 591,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Tough and Deadly (1995)'}
# {'_id': 593,
#  'genres': 'Drama|Thriller',
#  'title': 'Silence of the Lambs, The (1991)'}
# {'_id': 610,
#  'genres': 'Action|Adventure|Animation|Horror|Sci-Fi',
#  'title': 'Heavy Metal (1981)'}
# {'_id': 611,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Hellraiser: Bloodline (1996)'}
# {'_id': 614, 'genres': 'Drama|Thriller', 'title': 'Loaded (1994)'}
# {'_id': 624, 'genres': 'Action|Drama|Thriller', 'title': 'Condition Red (1995)'}
# {'_id': 628, 'genres': 'Drama|Thriller', 'title': 'Primal Fear (1996)'}
# {'_id': 627, 'genres': 'Drama|Thriller', 'title': 'Last Supper, The (1995)'}
# {'_id': 659, 'genres': 'Crime|Thriller', 'title': 'Purple Noon (1960)'}
# {'_id': 671,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'Mystery Science Theater 3000: The Movie (1996)'}
# {'_id': 662, 'genres': 'Thriller', 'title': 'Fear (1996)'}
# {'_id': 674, 'genres': 'Adventure|Sci-Fi', 'title': 'Barbarella (1968)'}
# {'_id': 678,
#  'genres': 'Drama|Thriller',
#  'title': 'Some Folks Call It a Sling Blade (1993)'}
# {'_id': 675,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Hostile Intentions (1994)'}
# {'_id': 692, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Solo (1996)'}
# {'_id': 695, 'genres': 'Mystery|Thriller', 'title': 'True Crime (1995)'}
# {'_id': 696, 'genres': 'Thriller', 'title': 'Butterfly Kiss (1995)'}
# {'_id': 640, 'genres': 'Drama|Thriller', 'title': 'Diabolique (1996)'}
# {'_id': 707,
#  'genres': 'Crime|Film-Noir|Thriller',
#  'title': 'Mulholland Falls (1996)'}
# {'_id': 718,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'Visitors, The (Les Visiteurs) (1993)'}
# {'_id': 680, 'genres': 'Sci-Fi', 'title': 'Alphaville (1965)'}
# {'_id': 736,
#  'genres': 'Action|Adventure|Romance|Thriller',
#  'title': 'Twister (1996)'}
# {'_id': 731, 'genres': 'Mystery|Thriller', 'title': "Heaven's Prisoners (1996)"}
# {'_id': 737, 'genres': 'Action|Sci-Fi', 'title': 'Barb Wire (1996)'}
# {'_id': 742, 'genres': 'Horror|Thriller', 'title': 'Thinner (1996)'}
# {'_id': 745,
#  'genres': 'Animation|Comedy|Thriller',
#  'title': 'Close Shave, A (1995)'}
# {'_id': 741,
#  'genres': 'Animation|Sci-Fi',
#  'title': 'Ghost in the Shell (Kokaku kidotai) (1995)'}
# {'_id': 748, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Arrival, The (1996)'}
# {'_id': 750,
#  'genres': 'Sci-Fi|War',
#  'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the '
#           'Bomb (1963)'}
# {'_id': 733, 'genres': 'Action|Adventure|Thriller', 'title': 'Rock, The (1996)'}
# {'_id': 780,
#  'genres': 'Action|Sci-Fi|War',
#  'title': 'Independence Day (ID4) (1996)'}
# {'_id': 782, 'genres': 'Thriller', 'title': 'Fan, The (1996)'}
# {'_id': 786, 'genres': 'Action|Thriller', 'title': 'Eraser (1996)'}
# {'_id': 788,
#  'genres': 'Comedy|Fantasy|Romance|Sci-Fi',
#  'title': 'Nutty Professor, The (1996)'}
# {'_id': 798, 'genres': 'Action|Adventure|Thriller', 'title': 'Daylight (1996)'}
# {'_id': 815, 'genres': 'Action|Mystery|Thriller', 'title': 'Power 98 (1995)'}
# {'_id': 832, 'genres': 'Drama|Thriller', 'title': 'Ransom (1996)'}
# {'_id': 836,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Chain Reaction (1996)'}
# {'_id': 839,
#  'genres': 'Action|Thriller',
#  'title': 'Crow: City of Angels, The (1996)'}
# {'_id': 849,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Escape from L.A. (1996)'}
# {'_id': 861, 'genres': 'Action|Thriller', 'title': 'Supercop (1992)'}
# {'_id': 866, 'genres': 'Crime|Drama|Romance|Thriller', 'title': 'Bound (1996)'}
# {'_id': 880,
#  'genres': 'Sci-Fi|Thriller',
#  'title': 'Island of Dr. Moreau, The (1996)'}
# {'_id': 882, 'genres': 'Drama|Thriller', 'title': 'Trigger Effect, The (1996)'}
# {'_id': 890, 'genres': 'Thriller', 'title': 'Baton Rouge (1988)'}
# {'_id': 891,
#  'genres': 'Horror|Thriller',
#  'title': 'Halloween: The Curse of Michael Myers (1995)'}
# {'_id': 903, 'genres': 'Mystery|Thriller', 'title': 'Vertigo (1958)'}
# {'_id': 904, 'genres': 'Mystery|Thriller', 'title': 'Rear Window (1954)'}
# {'_id': 906, 'genres': 'Mystery|Thriller', 'title': 'Gaslight (1944)'}
# {'_id': 908, 'genres': 'Drama|Thriller', 'title': 'North by Northwest (1959)'}
# {'_id': 911,
#  'genres': 'Comedy|Mystery|Romance|Thriller',
#  'title': 'Charade (1963)'}
# {'_id': 928, 'genres': 'Romance|Thriller', 'title': 'Rebecca (1940)'}
# {'_id': 929, 'genres': 'Thriller', 'title': 'Foreign Correspondent (1940)'}
# {'_id': 930,
#  'genres': 'Film-Noir|Romance|Thriller',
#  'title': 'Notorious (1946)'}
# {'_id': 931, 'genres': 'Mystery|Romance|Thriller', 'title': 'Spellbound (1945)'}
# {'_id': 933,
#  'genres': 'Comedy|Romance|Thriller',
#  'title': 'To Catch a Thief (1955)'}
# {'_id': 924,
#  'genres': 'Drama|Mystery|Sci-Fi|Thriller',
#  'title': '2001: A Space Odyssey (1968)'}
# {'_id': 965, 'genres': 'Thriller', 'title': '39 Steps, The (1935)'}
# {'_id': 968,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Night of the Living Dead (1968)'}
# {'_id': 992, 'genres': 'Thriller', 'title': "Rich Man's Wife, The (1996)"}
# {'_id': 990,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Maximum Risk (1996)'}
# {'_id': 1003, 'genres': 'Drama|Thriller', 'title': 'Extreme Measures (1996)'}
# {'_id': 1004, 'genres': 'Action|Thriller', 'title': 'Glimmer Man, The (1996)'}
# {'_id': 997, 'genres': 'Drama|Thriller', 'title': 'Caught (1996)'}
# {'_id': 1019,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': '20,000 Leagues Under the Sea (1954)'}
# {'_id': 1036, 'genres': 'Action|Thriller', 'title': 'Die Hard (1988)'}
# {'_id': 1037,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Lawnmower Man, The (1992)'}
# {'_id': 1047,
#  'genres': 'Action|Thriller',
#  'title': 'Long Kiss Goodnight, The (1996)'}
# {'_id': 1055, 'genres': 'Thriller', 'title': 'Shadow Conspiracy (1997)'}
# {'_id': 1069,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Murder, My Sweet (1944)'}
# {'_id': 1076, 'genres': 'Thriller', 'title': 'Innocents, The (1961)'}
# {'_id': 1077, 'genres': 'Comedy|Sci-Fi', 'title': 'Sleeper (1973)'}
# {'_id': 1086, 'genres': 'Mystery|Thriller', 'title': 'Dial M for Murder (1954)'}
# {'_id': 1089, 'genres': 'Crime|Thriller', 'title': 'Reservoir Dogs (1992)'}
# {'_id': 1092, 'genres': 'Mystery|Thriller', 'title': 'Basic Instinct (1992)'}
# {'_id': 1097,
#  'genres': "Children's|Drama|Fantasy|Sci-Fi",
#  'title': 'E.T. the Extra-Terrestrial (1982)'}
# {'_id': 1127,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Abyss, The (1989)'}
# {'_id': 1129,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Escape from New York (1981)'}
# {'_id': 1151, 'genres': 'Animation|Comedy|Thriller', 'title': 'Faust (1994)'}
# {'_id': 1152,
#  'genres': 'Crime|Film-Noir|Thriller',
#  'title': 'He Walked by Night (1948)'}
# {'_id': 1175, 'genres': 'Comedy|Sci-Fi', 'title': 'Delicatessen (1991)'}
# {'_id': 1165, 'genres': 'Drama|Thriller', 'title': 'Bloody Child, The (1996)'}
# {'_id': 1196,
#  'genres': 'Action|Adventure|Drama|Sci-Fi|War',
#  'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)'}
# {'_id': 1199, 'genres': 'Sci-Fi', 'title': 'Brazil (1985)'}
# {'_id': 1200, 'genres': 'Action|Sci-Fi|Thriller|War', 'title': 'Aliens (1986)'}
# {'_id': 1206, 'genres': 'Sci-Fi', 'title': 'Clockwork Orange, A (1971)'}
# {'_id': 1210,
#  'genres': 'Action|Adventure|Romance|Sci-Fi|War',
#  'title': 'Star Wars: Episode VI - Return of the Jedi (1983)'}
# {'_id': 1212, 'genres': 'Mystery|Thriller', 'title': 'Third Man, The (1949)'}
# {'_id': 1205,
#  'genres': "Action|Animation|Children's|Sci-Fi|Thriller|War",
#  'title': 'Transformers: The Movie, The (1986)'}
# {'_id': 1214,
#  'genres': 'Action|Horror|Sci-Fi|Thriller',
#  'title': 'Alien (1979)'}
# {'_id': 1215,
#  'genres': 'Action|Adventure|Comedy|Horror|Sci-Fi',
#  'title': 'Army of Darkness (1993)'}
# {'_id': 1219, 'genres': 'Horror|Thriller', 'title': 'Psycho (1960)'}
# {'_id': 1218,
#  'genres': 'Action|Thriller',
#  'title': 'Killer, The (Die xue shuang xiong) (1989)'}
# {'_id': 1227,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Once Upon a Time in America (1984)'}
# {'_id': 1232, 'genres': 'Mystery|Sci-Fi', 'title': 'Stalker (1979)'}
# {'_id': 1240,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Terminator, The (1984)'}
# {'_id': 1248,
#  'genres': 'Crime|Film-Noir|Thriller',
#  'title': 'Touch of Evil (1958)'}
# {'_id': 1249, 'genres': 'Thriller', 'title': 'Nikita (La Femme Nikita) (1990)'}
# {'_id': 1253,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Day the Earth Stood Still, The (1951)'}
# {'_id': 1252,
#  'genres': 'Film-Noir|Mystery|Thriller',
#  'title': 'Chinatown (1974)'}
# {'_id': 1260, 'genres': 'Crime|Film-Noir|Thriller', 'title': 'M (1931)'}
# {'_id': 1264,
#  'genres': 'Action|Drama|Mystery|Romance|Thriller',
#  'title': 'Diva (1981)'}
# {'_id': 1269,
#  'genres': 'Comedy|Mystery|Thriller',
#  'title': 'Arsenic and Old Lace (1944)'}
# {'_id': 1267,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Manchurian Candidate, The (1962)'}
# {'_id': 1270, 'genres': 'Comedy|Sci-Fi', 'title': 'Back to the Future (1985)'}
# {'_id': 1274,
#  'genres': 'Adventure|Animation|Sci-Fi|Thriller',
#  'title': 'Akira (1988)'}
# {'_id': 1301, 'genres': 'Sci-Fi', 'title': 'Forbidden Planet (1956)'}
# {'_id': 1306,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Until the End of the World (Bis ans Ende der Welt) (1991)'}
# {'_id': 1320,
#  'genres': 'Action|Horror|Sci-Fi|Thriller',
#  'title': 'Alien� (1992)'}
# {'_id': 1332, 'genres': 'Horror|Thriller', 'title': 'Believers, The (1987)'}
# {'_id': 1334, 'genres': 'Horror|Sci-Fi', 'title': 'Blob, The (1958)'}
# {'_id': 1344, 'genres': 'Film-Noir|Thriller', 'title': 'Cape Fear (1962)'}
# {'_id': 1343, 'genres': 'Thriller', 'title': 'Cape Fear (1991)'}
# {'_id': 1358, 'genres': 'Drama|Thriller', 'title': 'Sling Blade (1996)'}
# {'_id': 1356,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: First Contact (1996)'}
# {'_id': 1369,
#  'genres': 'Drama|Thriller',
#  'title': "I Can't Sleep (J'ai pas sommeil) (1994)"}
# {'_id': 1372,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek VI: The Undiscovered Country (1991)'}
# {'_id': 1373,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek V: The Final Frontier (1989)'}
# {'_id': 1370, 'genres': 'Action|Thriller', 'title': 'Die Hard 2 (1990)'}
# {'_id': 1374,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: The Wrath of Khan (1982)'}
# {'_id': 1375,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek III: The Search for Spock (1984)'}
# {'_id': 1371,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: The Motion Picture (1979)'}
# {'_id': 1352, 'genres': 'Crime|Thriller', 'title': 'Albino Alligator (1996)'}
# {'_id': 1376,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek IV: The Voyage Home (1986)'}
# {'_id': 1383,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Adrenalin: Fear the Rush (1996)'}
# {'_id': 1391,
#  'genres': 'Action|Comedy|Sci-Fi|War',
#  'title': 'Mars Attacks! (1996)'}
# {'_id': 1396, 'genres': 'Crime|Drama|Sci-Fi', 'title': 'Sneakers (1992)'}
# {'_id': 1355, 'genres': 'Horror|Thriller', 'title': 'Nightwatch (1997)'}
# {'_id': 1407, 'genres': 'Horror|Thriller', 'title': 'Scream (1996)'}
# {'_id': 1422, 'genres': 'Mystery|Thriller', 'title': 'Murder at 1600 (1997)'}
# {'_id': 1427, 'genres': 'Thriller', 'title': 'Turbulence (1997)'}
# {'_id': 1430, 'genres': 'Thriller', 'title': 'Underworld (1997)'}
# {'_id': 1438, 'genres': 'Action|Thriller', 'title': "Dante's Peak (1997)"}
# {'_id': 1459, 'genres': 'Mystery|Thriller', 'title': 'Absolute Power (1997)'}
# {'_id': 1472, 'genres': 'Crime|Thriller', 'title': 'City of Industry (1997)'}
# {'_id': 1480,
#  'genres': 'Action|Drama|Thriller',
#  'title': "Smilla's Sense of Snow (1997)"}
# {'_id': 1479, 'genres': 'Action|Romance|Thriller', 'title': 'Saint, The (1997)'}
# {'_id': 1483, 'genres': 'Drama|Thriller', 'title': 'Crash (1996)'}
# {'_id': 1488,
#  'genres': 'Action|Drama|Thriller|War',
#  'title': "Devil's Own, The (1997)"}
# {'_id': 1499, 'genres': 'Action|Adventure|Thriller', 'title': 'Anaconda (1997)'}
# {'_id': 1518, 'genres': 'Action|Thriller', 'title': 'Breakdown (1997)'}
# {'_id': 1527, 'genres': 'Action|Sci-Fi', 'title': 'Fifth Element, The (1997)'}
# {'_id': 1515, 'genres': 'Drama|Thriller', 'title': 'Volcano (1997)'}
# {'_id': 1544,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Lost World: Jurassic Park, The (1997)'}
# {'_id': 1552, 'genres': 'Action|Adventure|Thriller', 'title': 'Con Air (1997)'}
# {'_id': 1556,
#  'genres': 'Action|Romance|Thriller',
#  'title': 'Speed 2: Cruise Control (1997)'}
# {'_id': 1565, 'genres': 'Comedy|Thriller', 'title': 'Head Above Water (1996)'}
# {'_id': 1570, 'genres': 'Sci-Fi', 'title': 'Tetsuo II: Body Hammer (1992)'}
# {'_id': 1573, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Face/Off (1997)'}
# {'_id': 1580,
#  'genres': 'Action|Adventure|Comedy|Sci-Fi',
#  'title': 'Men in Black (1997)'}
# {'_id': 1584, 'genres': 'Drama|Sci-Fi', 'title': 'Contact (1997)'}
# {'_id': 1590,
#  'genres': 'Action|Mystery|Sci-Fi|Thriller',
#  'title': 'Event Horizon (1997)'}
# {'_id': 1598,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Desperate Measures (1998)'}
# {'_id': 1591,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Spawn (1997)'}
# {'_id': 1597,
#  'genres': 'Action|Mystery|Romance|Thriller',
#  'title': 'Conspiracy Theory (1997)'}
# {'_id': 1610,
#  'genres': 'Action|Thriller',
#  'title': 'Hunt for Red October, The (1990)'}
# {'_id': 1617,
#  'genres': 'Crime|Film-Noir|Mystery|Thriller',
#  'title': 'L.A. Confidential (1997)'}
# {'_id': 1603, 'genres': 'Sci-Fi|Thriller', 'title': 'Mimic (1997)'}
# {'_id': 1620,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Kiss the Girls (1997)'}
# {'_id': 1626,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Fire Down Below (1997)'}
# {'_id': 1625, 'genres': 'Mystery|Thriller', 'title': 'Game, The (1997)'}
# {'_id': 1631, 'genres': 'Thriller', 'title': 'Assignment, The (1997)'}
# {'_id': 1616,
#  'genres': 'Action|Thriller|War',
#  'title': 'Peacemaker, The (1997)'}
# {'_id': 1636, 'genres': 'Action|Thriller', 'title': 'Stag (1997)'}
# {'_id': 1644,
#  'genres': 'Horror|Mystery|Thriller',
#  'title': 'I Know What You Did Last Summer (1997)'}
# {'_id': 1647, 'genres': 'Crime|Thriller', 'title': 'Playing God (1997)'}
# {'_id': 1615, 'genres': 'Adventure|Thriller', 'title': 'Edge, The (1997)'}
# {'_id': 1648,
#  'genres': 'Comedy|Drama|Thriller',
#  'title': 'House of Yes, The (1997)'}
# {'_id': 1645,
#  'genres': 'Crime|Horror|Mystery|Thriller',
#  'title': "Devil's Advocate, The (1997)"}
# {'_id': 1608, 'genres': 'Action|Thriller', 'title': 'Air Force One (1997)'}
# {'_id': 1653, 'genres': 'Drama|Sci-Fi|Thriller', 'title': 'Gattaca (1997)'}
# {'_id': 1658,
#  'genres': 'Romance|Thriller',
#  'title': 'Life Less Ordinary, A (1997)'}
# {'_id': 1661, 'genres': 'Thriller', 'title': 'Switchback (1997)'}
# {'_id': 1683,
#  'genres': 'Drama|Romance|Thriller',
#  'title': 'Wings of the Dove, The (1997)'}
# {'_id': 1686, 'genres': 'Crime|Thriller', 'title': 'Red Corner (1997)'}
# {'_id': 1675, 'genres': 'Crime|Thriller', 'title': 'Incognito (1997)'}
# {'_id': 1687, 'genres': 'Action|Thriller', 'title': 'Jackal, The (1997)'}
# {'_id': 1690,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Alien: Resurrection (1997)'}
# {'_id': 1692, 'genres': 'Horror|Sci-Fi', 'title': 'Alien Escape (1995)'}
# {'_id': 1674, 'genres': 'Drama|Romance|Thriller', 'title': 'Witness (1985)'}
# {'_id': 1676,
#  'genres': 'Action|Adventure|Sci-Fi|War',
#  'title': 'Starship Troopers (1997)'}
# {'_id': 1709, 'genres': 'Thriller', 'title': 'Legal Deceit (1997)'}
# {'_id': 1717, 'genres': 'Horror|Thriller', 'title': 'Scream 2 (1997)'}
# {'_id': 1715, 'genres': 'Thriller', 'title': 'Office Killer (1997)'}
# {'_id': 1718, 'genres': 'Thriller', 'title': 'Stranger in the House (1997)'}
# {'_id': 1720,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Time Tracers (1995)'}
# {'_id': 1722,
#  'genres': 'Action|Romance|Thriller',
#  'title': 'Tomorrow Never Dies (1997)'}
# {'_id': 1732,
#  'genres': 'Comedy|Crime|Mystery|Thriller',
#  'title': 'Big Lebowski, The (1998)'}
# {'_id': 1744,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Firestorm (1998)'}
# {'_id': 1748,
#  'genres': 'Film-Noir|Sci-Fi|Thriller',
#  'title': 'Dark City (1998)'}
# {'_id': 1750,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': 'Star Kid (1997)'}
# {'_id': 1752, 'genres': 'Action|Thriller', 'title': 'Hard Rain (1998)'}
# {'_id': 1754, 'genres': 'Action|Mystery|Thriller', 'title': 'Fallen (1998)'}
# {'_id': 1762, 'genres': 'Action|Horror|Sci-Fi', 'title': 'Deep Rising (1998)'}
# {'_id': 1764, 'genres': 'Comedy|Thriller', 'title': 'Tainted (1998)'}
# {'_id': 1770, 'genres': 'Romance|Thriller', 'title': 'B. Monkey (1998)'}
# {'_id': 1769,
#  'genres': 'Action|Thriller',
#  'title': 'Replacement Killers, The (1998)'}
# {'_id': 1792, 'genres': 'Action|Thriller', 'title': 'U.S. Marshalls (1998)'}
# {'_id': 1798, 'genres': 'Thriller', 'title': 'Hush (1998)'}
# {'_id': 1779, 'genres': 'Adventure|Sci-Fi|Thriller', 'title': 'Sphere (1998)'}
# {'_id': 1783,
#  'genres': 'Film-Noir|Mystery|Thriller',
#  'title': 'Palmetto (1998)'}
# {'_id': 1805,
#  'genres': 'Crime|Drama|Mystery|Thriller',
#  'title': 'Wild Things (1998)'}
# {'_id': 1824, 'genres': 'Comedy|Thriller', 'title': 'Homegrown (1998)'}
# {'_id': 1831,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Lost in Space (1998)'}
# {'_id': 1833,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Mercury Rising (1998)'}
# {'_id': 1834,
#  'genres': 'Drama|Thriller',
#  'title': 'Spanish Prisoner, The (1997)'}
# {'_id': 1841,
#  'genres': 'Drama|Thriller',
#  'title': 'Gingerbread Man, The (1998)'}
# {'_id': 1845, 'genres': 'Comedy|Thriller', 'title': 'Zero Effect (1998)'}
# {'_id': 1847, 'genres': 'Drama|Thriller', 'title': 'Ratchet (1996)'}
# {'_id': 1852, 'genres': 'Drama|Thriller', 'title': 'Love Walked In (1998)'}
# {'_id': 1861, 'genres': 'Comedy|Thriller', 'title': 'Junk Mail (1997)'}
# {'_id': 1876,
#  'genres': 'Action|Drama|Sci-Fi|Thriller',
#  'title': 'Deep Impact (1998)'}
# {'_id': 1869, 'genres': 'Action|Thriller', 'title': 'Black Dog (1998)'}
# {'_id': 1862, 'genres': 'Horror|Sci-Fi', 'title': 'Species II (1998)'}
# {'_id': 1882, 'genres': 'Action|Sci-Fi', 'title': 'Godzilla (1998)'}
# {'_id': 1889, 'genres': 'Thriller', 'title': 'Insomnia (1997)'}
# {'_id': 1891, 'genres': 'Horror|Thriller', 'title': 'Ugly, The (1997)'}
# {'_id': 1892, 'genres': 'Mystery|Thriller', 'title': 'Perfect Murder, A (1998)'}
# {'_id': 1908, 'genres': 'Drama|Thriller', 'title': 'Resurrection Man (1998)'}
# {'_id': 1909,
#  'genres': 'Mystery|Sci-Fi|Thriller',
#  'title': 'X-Files: Fight the Future, The (1998)'}
# {'_id': 1917,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Armageddon (1998)'}
# {'_id': 1924,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Plan 9 from Outer Space (1958)'}
# {'_id': 1921, 'genres': 'Sci-Fi|Thriller', 'title': 'Pi (1998)'}
# {'_id': 1953,
#  'genres': 'Action|Crime|Drama|Thriller',
#  'title': 'French Connection, The (1971)'}
# {'_id': 1965, 'genres': 'Comedy|Sci-Fi', 'title': 'Repo Man (1984)'}
# {'_id': 1994, 'genres': 'Horror|Thriller', 'title': 'Poltergeist (1982)'}
# {'_id': 1995,
#  'genres': 'Horror|Thriller',
#  'title': 'Poltergeist II: The Other Side (1986)'}
# {'_id': 1996, 'genres': 'Horror|Thriller', 'title': 'Poltergeist III (1988)'}
# {'_id': 2011,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'Back to the Future Part II (1989)'}
# {'_id': 2010, 'genres': 'Sci-Fi', 'title': 'Metropolis (1926)'}
# {'_id': 2012,
#  'genres': 'Comedy|Sci-Fi|Western',
#  'title': 'Back to the Future Part III (1990)'}
# {'_id': 2009, 'genres': 'Sci-Fi|Thriller', 'title': 'Soylent Green (1973)'}
# {'_id': 2021, 'genres': 'Fantasy|Sci-Fi', 'title': 'Dune (1984)'}
# {'_id': 2026,
#  'genres': 'Horror|Thriller',
#  'title': 'Disturbing Behavior (1998)'}
# {'_id': 2034, 'genres': 'Sci-Fi', 'title': 'Black Hole, The (1979)'}
# {'_id': 2038,
#  'genres': "Children's|Comedy|Sci-Fi",
#  'title': 'Cat from Outer Space, The (1978)'}
# {'_id': 2053,
#  'genres': "Children's|Comedy|Sci-Fi",
#  'title': 'Honey, I Blew Up the Kid (1992)'}
# {'_id': 2054,
#  'genres': "Adventure|Children's|Comedy|Fantasy|Sci-Fi",
#  'title': 'Honey, I Shrunk the Kids (1989)'}
# {'_id': 2058, 'genres': 'Action|Thriller', 'title': 'Negotiator, The (1998)'}
# {'_id': 2046,
#  'genres': "Adventure|Children's|Sci-Fi",
#  'title': 'Flight of the Navigator (1986)'}
# {'_id': 2091,
#  'genres': "Children's|Sci-Fi",
#  'title': 'Return from Witch Mountain (1978)'}
# {'_id': 2093,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': 'Return to Oz (1985)'}
# {'_id': 2094,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Rocketeer, The (1991)'}
# {'_id': 2105,
#  'genres': 'Action|Adventure|Fantasy|Sci-Fi',
#  'title': 'Tron (1982)'}
# {'_id': 2107, 'genres': 'Horror|Thriller', 'title': 'Halloween: H20 (1998)'}
# {'_id': 2110,
#  'genres': 'Comedy|Crime|Thriller',
#  'title': "Dead Men Don't Wear Plaid (1982)"}
# {'_id': 2126,
#  'genres': 'Action|Crime|Mystery|Thriller',
#  'title': 'Snake Eyes (1998)'}
# {'_id': 2140,
#  'genres': "Children's|Fantasy|Sci-Fi",
#  'title': 'Dark Crystal, The (1982)'}
# {'_id': 2121, 'genres': 'Horror|Thriller', 'title': 'Cujo (1983)'}
# {'_id': 2122,
#  'genres': 'Horror|Thriller',
#  'title': 'Children of the Corn (1984)'}
# {'_id': 2118, 'genres': 'Horror|Thriller', 'title': 'Dead Zone, The (1983)'}
# {'_id': 2116,
#  'genres': "Adventure|Animation|Children's|Sci-Fi",
#  'title': 'Lord of the Rings, The (1978)'}
# {'_id': 2117, 'genres': 'Drama|Sci-Fi', 'title': 'Nineteen Eighty-Four (1984)'}
# {'_id': 2113, 'genres': 'Horror|Thriller', 'title': 'Graveyard Shift (1990)'}
# {'_id': 2160, 'genres': 'Horror|Thriller', 'title': "Rosemary's Baby (1968)"}
# {'_id': 2173,
#  'genres': 'Adventure|Fantasy|Sci-Fi',
#  'title': 'Navigator: A Mediaeval Odyssey, The (1988)'}
# {'_id': 2176, 'genres': 'Thriller', 'title': 'Rope (1948)'}
# {'_id': 2177, 'genres': 'Comedy|Thriller', 'title': 'Family Plot (1976)'}
# {'_id': 2178, 'genres': 'Thriller', 'title': 'Frenzy (1972)'}
# {'_id': 2180, 'genres': 'Thriller', 'title': 'Torn Curtain (1966)'}
# {'_id': 2181, 'genres': 'Thriller', 'title': 'Marnie (1964)'}
# {'_id': 2179, 'genres': 'Thriller', 'title': 'Topaz (1969)'}
# {'_id': 2182,
#  'genres': 'Drama|Film-Noir|Thriller',
#  'title': 'Wrong Man, The (1956)'}
# {'_id': 2184,
#  'genres': 'Mystery|Thriller',
#  'title': 'Trouble with Harry, The (1955)'}
# {'_id': 2185, 'genres': 'Thriller', 'title': 'I Confess (1953)'}
# {'_id': 2183,
#  'genres': 'Thriller',
#  'title': 'Man Who Knew Too Much, The (1956)'}
# {'_id': 2187, 'genres': 'Mystery|Thriller', 'title': 'Stage Fright (1950)'}
# {'_id': 2186,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Strangers on a Train (1951)'}
# {'_id': 2203,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Shadow of a Doubt (1943)'}
# {'_id': 2204, 'genres': 'Thriller', 'title': 'Saboteur (1942)'}
# {'_id': 2202, 'genres': 'Drama|Thriller|War', 'title': 'Lifeboat (1944)'}
# {'_id': 2206, 'genres': 'Mystery|Thriller', 'title': 'Suspicion (1941)'}
# {'_id': 2209, 'genres': 'Crime|Thriller', 'title': 'Young and Innocent (1937)'}
# {'_id': 2211, 'genres': 'Thriller', 'title': 'Secret Agent (1936)'}
# {'_id': 2208,
#  'genres': 'Comedy|Mystery|Romance|Thriller',
#  'title': 'Lady Vanishes, The (1938)'}
# {'_id': 2212,
#  'genres': 'Thriller',
#  'title': 'Man Who Knew Too Much, The (1934)'}
# {'_id': 2210, 'genres': 'Thriller', 'title': 'Sabotage (1936)'}
# {'_id': 2214, 'genres': 'Thriller', 'title': 'Number Seventeen (1932)'}
# {'_id': 2219, 'genres': 'Mystery|Thriller', 'title': 'Murder! (1930)'}
# {'_id': 2232, 'genres': 'Sci-Fi|Thriller', 'title': 'Cube (1997)'}
# {'_id': 2227, 'genres': 'Thriller', 'title': 'Lodger, The (1926)'}
# {'_id': 2221, 'genres': 'Thriller', 'title': 'Blackmail (1929)'}
# {'_id': 2256, 'genres': 'Horror|Sci-Fi', 'title': 'Parasite (1982)'}
# {'_id': 2263, 'genres': 'Thriller', 'title': 'Seventh Sign, The (1988)'}
# {'_id': 2267, 'genres': 'Mystery|Thriller', 'title': 'Mortal Thoughts (1991)'}
# {'_id': 2273, 'genres': 'Action|Thriller', 'title': 'Rush Hour (1998)'}
# {'_id': 2275,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Six-String Samurai (1998)'}
# {'_id': 2279, 'genres': 'Horror|Thriller', 'title': 'Urban Legend (1998)'}
# {'_id': 2278, 'genres': 'Action|Crime|Thriller', 'title': 'Ronin (1998)'}
# {'_id': 2288,
#  'genres': 'Action|Horror|Sci-Fi|Thriller',
#  'title': 'Thing, The (1982)'}
# {'_id': 2287, 'genres': 'Sci-Fi|Thriller|War', 'title': 'Them! (1954)'}
# {'_id': 2298, 'genres': 'Thriller', 'title': 'Strangeland (1998)'}
# {'_id': 2311, 'genres': 'Mystery|Sci-Fi', 'title': '2010 (1984)'}
# {'_id': 2315, 'genres': 'Horror|Thriller', 'title': 'Bride of Chucky (1998)'}
# {'_id': 2320, 'genres': 'Drama|Thriller', 'title': 'Apt Pupil (1998)'}
# {'_id': 2322,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller|War',
#  'title': 'Soldier (1998)'}
# {'_id': 2326, 'genres': 'Drama|Thriller', 'title': 'Shattered Image (1998)'}
# {'_id': 2334, 'genres': 'Action|Thriller', 'title': 'Siege, The (1998)'}
# {'_id': 2338,
#  'genres': 'Horror|Mystery|Thriller',
#  'title': 'I Still Know What You Did Last Summer (1998)'}
# {'_id': 2344,
#  'genres': 'Action|Adventure|Drama|Thriller',
#  'title': 'Runaway Train (1985)'}
# {'_id': 2346,
#  'genres': 'Sci-Fi|Thriller',
#  'title': 'Stepford Wives, The (1975)'}
# {'_id': 2349, 'genres': 'Comedy|Thriller', 'title': 'Mona Lisa (1986)'}
# {'_id': 2353, 'genres': 'Action|Thriller', 'title': 'Enemy of the State (1998)'}
# {'_id': 2363, 'genres': 'Action|Sci-Fi', 'title': 'Godzilla (Gojira) (1954)'}
# {'_id': 2364, 'genres': 'Action|Sci-Fi', 'title': 'Godzilla (Gojira) (1984)'}
# {'_id': 2365,
#  'genres': 'Action|Sci-Fi',
#  'title': 'King Kong vs. Godzilla (Kingukongu tai Gojira) (1962)'}
# {'_id': 2377, 'genres': 'Horror|Sci-Fi', 'title': 'Lifeforce (1985)'}
# {'_id': 2389, 'genres': 'Crime|Horror|Thriller', 'title': 'Psycho (1998)'}
# {'_id': 2391, 'genres': 'Crime|Thriller', 'title': 'Simple Plan, A (1998)'}
# {'_id': 2407, 'genres': 'Comedy|Sci-Fi', 'title': 'Cocoon (1985)'}
# {'_id': 2408, 'genres': 'Comedy|Sci-Fi', 'title': 'Cocoon: The Return (1988)'}
# {'_id': 2419, 'genres': 'Drama|Thriller', 'title': 'Extremities (1986)'}
# {'_id': 2428, 'genres': 'Horror|Sci-Fi', 'title': 'Faculty, The (1998)'}
# {'_id': 2393,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Star Trek: Insurrection (1998)'}
# {'_id': 2438, 'genres': 'Drama|Thriller', 'title': 'Outside Ozona (1998)'}
# {'_id': 2446, 'genres': 'Thriller', 'title': 'In Dreams (1999)'}
# {'_id': 2448, 'genres': 'Horror|Sci-Fi', 'title': 'Virus (1999)'}
# {'_id': 2454, 'genres': 'Horror|Sci-Fi', 'title': 'Fly, The (1958)'}
# {'_id': 2456, 'genres': 'Horror|Sci-Fi', 'title': 'Fly II, The (1989)'}
# {'_id': 2450,
#  'genres': "Adventure|Children's|Sci-Fi",
#  'title': 'Howard the Duck (1986)'}
# {'_id': 2455, 'genres': 'Horror|Sci-Fi', 'title': 'Fly, The (1986)'}
# {'_id': 2468,
#  'genres': 'Action|Comedy|Romance|Thriller',
#  'title': "Jumpin' Jack Flash (1986)"}
# {'_id': 2475, 'genres': 'Action|Mystery|Thriller', 'title': '52 Pick-Up (1986)'}
# {'_id': 2479, 'genres': 'Drama|Thriller', 'title': 'Gloria (1999)'}
# {'_id': 2483,
#  'genres': 'Comedy|Horror|Thriller',
#  'title': 'Day of the Beast, The (El D�a de la bestia) (1995)'}
# {'_id': 2490, 'genres': 'Action|Thriller', 'title': 'Payback (1999)'}
# {'_id': 2488, 'genres': 'Drama|Horror|Thriller', 'title': 'Peeping Tom (1960)'}
# {'_id': 2495,
#  'genres': 'Animation|Sci-Fi',
#  'title': 'Fantastic Planet, The (La Plan�te sauvage) (1973)'}
# {'_id': 2505, 'genres': 'Thriller', 'title': '8MM (1999)'}
# {'_id': 2498, 'genres': 'Comedy|Sci-Fi', 'title': 'My Favorite Martian (1999)'}
# {'_id': 2525, 'genres': 'Action|Horror|Sci-Fi', 'title': 'Alligator (1980)'}
# {'_id': 2527,
#  'genres': 'Action|Sci-Fi|Thriller|Western',
#  'title': 'Westworld (1973)'}
# {'_id': 2526, 'genres': 'Sci-Fi', 'title': 'Meteor (1979)'}
# {'_id': 2528,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': "Logan's Run (1976)"}
# {'_id': 2529, 'genres': 'Action|Sci-Fi', 'title': 'Planet of the Apes (1968)'}
# {'_id': 2531,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Battle for the Planet of the Apes (1973)'}
# {'_id': 2523, 'genres': 'Drama|Thriller', 'title': 'Rollercoaster (1977)'}
# {'_id': 2530,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Beneath the Planet of the Apes (1970)'}
# {'_id': 2533,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Escape from the Planet of the Apes (1971)'}
# {'_id': 2532,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Conquest of the Planet of the Apes (1972)'}
# {'_id': 2549, 'genres': 'Action|Sci-Fi', 'title': 'Wing Commander (1999)'}
# {'_id': 2551, 'genres': 'Drama|Thriller', 'title': 'Dead Ringers (1988)'}
# {'_id': 2553,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Village of the Damned (1960)'}
# {'_id': 2554,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Children of the Damned (1963)'}
# {'_id': 2540,
#  'genres': 'Action|Crime|Drama|Thriller',
#  'title': 'Corruptor, The (1999)'}
# {'_id': 2561, 'genres': 'Crime|Thriller', 'title': 'True Crime (1999)'}
# {'_id': 2550, 'genres': 'Horror|Thriller', 'title': 'Haunting, The (1963)'}
# {'_id': 2542,
#  'genres': 'Comedy|Crime|Thriller',
#  'title': 'Lock, Stock & Two Smoking Barrels (1998)'}
# {'_id': 2571, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Matrix, The (1999)'}
# {'_id': 2578, 'genres': 'Sci-Fi', 'title': 'Sticky Fingers of Time, The (1997)'}
# {'_id': 2586,
#  'genres': 'Comedy|Crime|Thriller',
#  'title': 'Goodbye, Lover (1999)'}
# {'_id': 2594,
#  'genres': 'Drama|Romance|Sci-Fi',
#  'title': 'Open Your Eyes (Abre los ojos) (1997)'}
# {'_id': 2600, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'eXistenZ (1999)'}
# {'_id': 2602,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'Mighty Peking Man (Hsing hsing wang) (1977)'}
# {'_id': 2605, 'genres': 'Crime|Thriller', 'title': 'Entrapment (1999)'}
# {'_id': 2608, 'genres': 'Thriller', 'title': 'Heaven (1998)'}
# {'_id': 2614,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Chopping Mall (a.k.a. Killbots) (1986)'}
# {'_id': 2615,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'My Science Project (1985)'}
# {'_id': 2613,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Night of the Comet (1984)'}
# {'_id': 2617,
#  'genres': 'Action|Adventure|Horror|Thriller',
#  'title': 'Mummy, The (1999)'}
# {'_id': 2631,
#  'genres': 'Comedy|Film-Noir|Thriller',
#  'title': 'Frogs for Snakes (1998)'}
# {'_id': 2640, 'genres': 'Action|Adventure|Sci-Fi', 'title': 'Superman (1978)'}
# {'_id': 2628,
#  'genres': 'Action|Adventure|Fantasy|Sci-Fi',
#  'title': 'Star Wars: Episode I - The Phantom Menace (1999)'}
# {'_id': 2641,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Superman II (1980)'}
# {'_id': 2643,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Superman IV: The Quest for Peace (1987)'}
# {'_id': 2642,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Superman III (1983)'}
# {'_id': 2656, 'genres': 'Horror|Sci-Fi', 'title': 'Tarantula (1955)'}
# {'_id': 2657,
#  'genres': 'Comedy|Horror|Musical|Sci-Fi',
#  'title': 'Rocky Horror Picture Show, The (1975)'}
# {'_id': 2661, 'genres': 'Sci-Fi', 'title': 'It Came from Outer Space (1953)'}
# {'_id': 2662,
#  'genres': 'Action|Sci-Fi|War',
#  'title': 'War of the Worlds, The (1953)'}
# {'_id': 2658, 'genres': 'Sci-Fi', 'title': 'Flying Saucer, The (1950)'}
# {'_id': 2663,
#  'genres': 'Sci-Fi',
#  'title': 'It Came from Beneath the Sea (1955)'}
# {'_id': 2664,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Invasion of the Body Snatchers (1956)'}
# {'_id': 2666, 'genres': 'Sci-Fi', 'title': 'It Conquered the World (1956)'}
# {'_id': 2667, 'genres': 'Sci-Fi', 'title': 'Mole People, The (1956)'}
# {'_id': 2660,
#  'genres': 'Sci-Fi',
#  'title': 'Thing From Another World, The (1951)'}
# {'_id': 2668, 'genres': 'Horror|Sci-Fi', 'title': 'Swamp Thing (1982)'}
# {'_id': 2665,
#  'genres': 'Sci-Fi',
#  'title': 'Earth Vs. the Flying Saucers (1956)'}
# {'_id': 2672,
#  'genres': 'Drama|Sci-Fi|Thriller',
#  'title': 'Thirteenth Floor, The (1999)'}
# {'_id': 2676, 'genres': 'Drama|Thriller', 'title': 'Instinct (1999)'}
# {'_id': 2681,
#  'genres': 'Comedy|Romance|Sci-Fi',
#  'title': 'Free Enterprise (1998)'}
# {'_id': 2688,
#  'genres': 'Drama|Thriller',
#  'title': "General's Daughter, The (1999)"}
# {'_id': 2707, 'genres': 'Thriller', 'title': 'Arlington Road (1999)'}
# {'_id': 2713, 'genres': 'Horror|Thriller', 'title': 'Lake Placid (1999)'}
# {'_id': 2698, 'genres': 'Sci-Fi', 'title': 'Zone 39 (1997)'}
# {'_id': 2701,
#  'genres': 'Action|Sci-Fi|Western',
#  'title': 'Wild Wild West (1999)'}
# {'_id': 2719, 'genres': 'Horror|Thriller', 'title': 'Haunting, The (1999)'}
# {'_id': 2699,
#  'genres': 'Action|Comedy|Sci-Fi|Thriller',
#  'title': 'Arachnophobia (1990)'}
# {'_id': 2722,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Deep Blue Sea (1999)'}
# {'_id': 2753, 'genres': 'Thriller', 'title': 'Bedroom Window, The (1987)'}
# {'_id': 2762, 'genres': 'Thriller', 'title': 'Sixth Sense, The (1999)'}
# {'_id': 2763,
#  'genres': 'Action|Thriller',
#  'title': 'Thomas Crown Affair, The (1999)'}
# {'_id': 2764,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Thomas Crown Affair, The (1968)'}
# {'_id': 2741, 'genres': 'Action|Thriller', 'title': 'No Mercy (1986)'}
# {'_id': 2778, 'genres': 'Thriller', 'title': 'Never Talk to Strangers (1995)'}
# {'_id': 2802,
#  'genres': 'Action|Romance|Thriller',
#  'title': 'Tequila Sunrise (1988)'}
# {'_id': 2812, 'genres': 'Action|Thriller', 'title': 'In Too Deep (1999)'}
# {'_id': 2806,
#  'genres': 'Comedy|Thriller',
#  'title': 'Teaching Mrs. Tingle (1999)'}
# {'_id': 2803, 'genres': 'Thriller', 'title': 'Pelican Brief, The (1993)'}
# {'_id': 2808, 'genres': 'Action|Sci-Fi', 'title': 'Universal Soldier (1992)'}
# {'_id': 2807,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Universal Soldier: The Return (1999)'}
# {'_id': 2827,
#  'genres': 'Sci-Fi|Thriller',
#  'title': "Astronaut's Wife, The (1999)"}
# {'_id': 2826,
#  'genres': 'Action|Horror|Thriller',
#  'title': '13th Warrior, The (1999)'}
# {'_id': 2819, 'genres': 'Thriller', 'title': 'Three Days of the Condor (1975)'}
# {'_id': 2835, 'genres': 'Action|Thriller', 'title': 'Chill Factor (1999)'}
# {'_id': 2840, 'genres': 'Thriller', 'title': 'Stigmata (1999)'}
# {'_id': 2841, 'genres': 'Thriller', 'title': 'Stir of Echoes (1999)'}
# {'_id': 2856, 'genres': 'Thriller', 'title': 'I Saw What You Did (1965)'}
# {'_id': 2850, 'genres': 'Drama|Thriller', 'title': 'Public Access (1993)'}
# {'_id': 2851, 'genres': 'Adventure|Sci-Fi|Thriller', 'title': 'Saturn 3 (1979)'}
# {'_id': 2871, 'genres': 'Adventure|Thriller', 'title': 'Deliverance (1972)'}
# {'_id': 2881, 'genres': 'Action|Thriller', 'title': 'Double Jeopardy (1999)'}
# {'_id': 2901, 'genres': 'Horror|Sci-Fi', 'title': 'Phantasm (1979)'}
# {'_id': 2900, 'genres': 'Horror|Sci-Fi', 'title': 'Monkey Shines (1988)'}
# {'_id': 2902, 'genres': 'Horror|Thriller', 'title': 'Psycho II (1983)'}
# {'_id': 2903, 'genres': 'Horror|Thriller', 'title': 'Psycho III (1986)'}
# {'_id': 2917, 'genres': 'Crime|Thriller', 'title': 'Body Heat (1981)'}
# {'_id': 2916,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Total Recall (1990)'}
# {'_id': 2939, 'genres': 'Drama|Thriller', 'title': 'Niagara (1953)'}
# {'_id': 2952,
#  'genres': 'Crime|Thriller',
#  'title': 'Hard 8 (a.k.a. Sydney, a.k.a. Hard Eight) (1996)'}
# {'_id': 2956,
#  'genres': 'Action|Crime|Thriller',
#  'title': 'Someone to Watch Over Me (1987)'}
# {'_id': 2967, 'genres': 'Drama|Thriller', 'title': 'Bad Seed, The (1956)'}
# {'_id': 2968,
#  'genres': 'Adventure|Fantasy|Sci-Fi',
#  'title': 'Time Bandits (1981)'}
# {'_id': 2974, 'genres': 'Horror|Thriller', 'title': 'Bats (1999)'}
# {'_id': 2983, 'genres': 'Thriller', 'title': 'Ipcress File, The (1965)'}
# {'_id': 2985, 'genres': 'Action|Crime|Sci-Fi', 'title': 'Robocop (1987)'}
# {'_id': 2982, 'genres': 'Horror|Thriller', 'title': 'Guardian, The (1990)'}
# {'_id': 2986, 'genres': 'Action|Crime|Sci-Fi', 'title': 'Robocop 2 (1990)'}
# {'_id': 2992, 'genres': 'Horror|Thriller', 'title': 'Rawhead Rex (1986)'}
# {'_id': 3005, 'genres': 'Thriller', 'title': 'Bone Collector, The (1999)'}
# {'_id': 3008, 'genres': 'Thriller', 'title': 'Last Night (1998)'}
# {'_id': 3015, 'genres': 'Thriller', 'title': 'Coma (1978)'}
# {'_id': 3024, 'genres': 'Horror|Sci-Fi', 'title': 'Piranha (1978)'}
# {'_id': 3032, 'genres': 'Sci-Fi', 'title': 'Omega Man, The (1971)'}
# {'_id': 3033, 'genres': 'Comedy|Sci-Fi', 'title': 'Spaceballs (1987)'}
# {'_id': 3044,
#  'genres': 'Mystery|Romance|Thriller',
#  'title': 'Dead Again (1991)'}
# {'_id': 3056, 'genres': 'Thriller', 'title': 'Oxygen (1999)'}
# {'_id': 3058, 'genres': 'Horror|Sci-Fi', 'title': 'Ape, The (1940)'}
# {'_id': 3055, 'genres': 'Thriller', 'title': "Felicia's Journey (1999)"}
# {'_id': 3070,
#  'genres': 'Adventure|Comedy|Sci-Fi',
#  'title': 'Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)'}
# {'_id': 3064, 'genres': 'Thriller', 'title': 'Poison Ivy: New Seduction (1997)'}
# {'_id': 3082,
#  'genres': 'Action|Thriller',
#  'title': 'World Is Not Enough, The (1999)'}
# {'_id': 3063, 'genres': 'Thriller', 'title': 'Poison Ivy (1992)'}
# {'_id': 3080,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Goodbye, 20th Century (Zbogum na dvadesetiot vek) (1998)'}
# {'_id': 3075, 'genres': 'Thriller', 'title': 'Repulsion (1965)'}
# {'_id': 3101, 'genres': 'Thriller', 'title': 'Fatal Attraction (1987)'}
# {'_id': 3102, 'genres': 'Thriller', 'title': 'Jagged Edge (1985)'}
# {'_id': 3113, 'genres': 'Action|Thriller', 'title': 'End of Days (1999)'}
# {'_id': 3147, 'genres': 'Drama|Thriller', 'title': 'Green Mile, The (1999)'}
# {'_id': 3175,
#  'genres': 'Adventure|Comedy|Sci-Fi',
#  'title': 'Galaxy Quest (1999)'}
# {'_id': 3176,
#  'genres': 'Drama|Mystery|Thriller',
#  'title': 'Talented Mr. Ripley, The (1999)'}
# {'_id': 3156,
#  'genres': 'Comedy|Drama|Sci-Fi',
#  'title': 'Bicentennial Man (1999)'}
# {'_id': 3190, 'genres': 'Adventure|Sci-Fi', 'title': 'Supernova (2000)'}
# {'_id': 3204, 'genres': 'Thriller', 'title': 'Boys from Brazil, The (1978)'}
# {'_id': 3203, 'genres': 'Thriller', 'title': 'Dead Calm (1989)'}
# {'_id': 3219, 'genres': 'Thriller', 'title': 'Pacific Heights (1990)'}
# {'_id': 3227,
#  'genres': 'Comedy|Drama|Thriller',
#  'title': 'Not Love, Just Frenzy (M�s que amor, frenes�) (1996)'}
# {'_id': 3230, 'genres': 'Thriller', 'title': 'Odessa File, The (1974)'}
# {'_id': 3238, 'genres': 'Thriller', 'title': 'Eye of the Beholder (1999)'}
# {'_id': 3267, 'genres': 'Action|Thriller', 'title': 'Mariachi, El (1992)'}
# {'_id': 3269,
#  'genres': 'Adventure|Romance|Sci-Fi',
#  'title': 'Forever Young (1992)'}
# {'_id': 3273, 'genres': 'Horror|Mystery|Thriller', 'title': 'Scream 3 (2000)'}
# {'_id': 3249,
#  'genres': 'Thriller',
#  'title': 'Hand That Rocks the Cradle, The (1992)'}
# {'_id': 3256, 'genres': 'Action|Thriller', 'title': 'Patriot Games (1992)'}
# {'_id': 3257,
#  'genres': 'Action|Drama|Romance|Thriller',
#  'title': 'Bodyguard, The (1992)'}
# {'_id': 3291, 'genres': 'Thriller', 'title': 'Trois (2000)'}
# {'_id': 3293, 'genres': 'Drama|Sci-Fi', 'title': 'Conceiving Ada (1997)'}
# {'_id': 3300, 'genres': 'Action|Sci-Fi', 'title': 'Pitch Black (2000)'}
# {'_id': 3326,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'What Planet Are You From? (2000)'}
# {'_id': 3334,
#  'genres': 'Crime|Drama|Film-Noir|Thriller',
#  'title': 'Key Largo (1948)'}
# {'_id': 3316, 'genres': 'Action|Thriller', 'title': 'Reindeer Games (2000)'}
# {'_id': 3340, 'genres': 'Horror|Sci-Fi', 'title': 'Bride of the Monster (1956)'}
# {'_id': 3348, 'genres': 'Crime|Thriller', 'title': 'Night Visitor, The (1970)'}
# {'_id': 3354, 'genres': 'Sci-Fi', 'title': 'Mission to Mars (2000)'}
# {'_id': 3355, 'genres': 'Thriller', 'title': 'Ninth Gate, The (2000)'}
# {'_id': 3370, 'genres': 'Drama|Thriller', 'title': 'Betrayed (1988)'}
# {'_id': 3375, 'genres': 'Sci-Fi', 'title': 'Destination Moon (1950)'}
# {'_id': 3318, 'genres': 'Thriller', 'title': 'Deterrence (1998)'}
# {'_id': 3401,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'Baby... Secret of the Lost Legend (1985)'}
# {'_id': 3417,
#  'genres': 'Adventure|Comedy|Sci-Fi',
#  'title': 'Crimson Pirate, The (1952)'}
# {'_id': 3420,
#  'genres': 'Drama|Thriller',
#  'title': '...And Justice for All (1979)'}
# {'_id': 3403, 'genres': 'Drama|Thriller', 'title': 'Raise the Titanic (1980)'}
# {'_id': 3409, 'genres': 'Drama|Thriller', 'title': 'Final Destination (2000)'}
# {'_id': 3443,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Born American (1986)'}
# {'_id': 3445,
#  'genres': 'Mystery|Thriller',
#  'title': 'Eyes of Laura Mars (1978)'}
# {'_id': 3455, 'genres': 'Drama|Thriller', 'title': 'Buddy Boy (1999)'}
# {'_id': 3461,
#  'genres': 'Adventure|Drama|Thriller',
#  'title': 'Lord of the Flies (1963)'}
# {'_id': 3464, 'genres': 'Sci-Fi|Thriller', 'title': 'Solar Crisis (1993)'}
# {'_id': 3474, 'genres': 'Sci-Fi|Thriller', 'title': 'Retroactive (1997)'}
# {'_id': 3471,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Close Encounters of the Third Kind (1977)'}
# {'_id': 3476,
#  'genres': 'Horror|Mystery|Thriller',
#  'title': "Jacob's Ladder (1990)"}
# {'_id': 3484, 'genres': 'Thriller', 'title': 'Skulls, The (2000)'}
# {'_id': 3486, 'genres': 'Sci-Fi', 'title': 'Devil Girl From Mars (1954)'}
# {'_id': 3488,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Hideous Sun Demon, The (1959)'}
# {'_id': 3503, 'genres': 'Drama|Sci-Fi', 'title': 'Solaris (Solyaris) (1972)'}
# {'_id': 3505, 'genres': 'Thriller', 'title': 'No Way Out (1987)'}
# {'_id': 3510, 'genres': 'Drama|Thriller', 'title': 'Frequency (2000)'}
# {'_id': 3513, 'genres': 'Drama|Thriller', 'title': 'Rules of Engagement (2000)'}
# {'_id': 3518,
#  'genres': 'Drama|Thriller',
#  'title': 'End of Violence, The (1997)'}
# {'_id': 3523, 'genres': 'Action|Thriller', 'title': 'Taffin (1988)'}
# {'_id': 3529,
#  'genres': 'Crime|Thriller',
#  'title': 'Postman Always Rings Twice, The (1981)'}
# {'_id': 3527, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Predator (1987)'}
# {'_id': 3535,
#  'genres': 'Comedy|Horror|Thriller',
#  'title': 'American Psycho (2000)'}
# {'_id': 3540, 'genres': 'Romance|Thriller', 'title': 'Passion of Mind (1999)'}
# {'_id': 3546,
#  'genres': 'Drama|Thriller',
#  'title': 'What Ever Happened to Baby Jane? (1962)'}
# {'_id': 3551, 'genres': 'Thriller', 'title': 'Marathon Man (1976)'}
# {'_id': 3553, 'genres': 'Drama|Thriller', 'title': 'Gossip (2000)'}
# {'_id': 3555, 'genres': 'Action|Thriller', 'title': 'U-571 (2000)'}
# {'_id': 3557, 'genres': 'Thriller', 'title': 'Jennifer 8 (1992)'}
# {'_id': 3572, 'genres': 'Horror|Sci-Fi', 'title': 'Carnosaur (1993)'}
# {'_id': 3573, 'genres': 'Horror|Sci-Fi', 'title': 'Carnosaur 2 (1995)'}
# {'_id': 3574,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Carnosaur 3: Primal Species (1996)'}
# {'_id': 3576, 'genres': 'Action|Horror|Sci-Fi', 'title': 'Hidden, The (1987)'}
# {'_id': 3584,
#  'genres': 'Action|Drama|Romance|Thriller',
#  'title': 'Breathless (1983)'}
# {'_id': 3592,
#  'genres': 'Animation|Sci-Fi',
#  'title': 'Time Masters (Les Ma�tres du Temps) (1982)'}
# {'_id': 3593, 'genres': 'Action|Sci-Fi', 'title': 'Battlefield Earth (2000)'}
# {'_id': 3623,
#  'genres': 'Action|Thriller',
#  'title': 'Mission: Impossible 2 (2000)'}
# {'_id': 3627, 'genres': 'Horror|Thriller', 'title': 'Carnival of Souls (1962)'}
# {'_id': 3634, 'genres': 'Thriller', 'title': 'Seven Days in May (1964)'}
# {'_id': 3638, 'genres': 'Action|Romance|Sci-Fi', 'title': 'Moonraker (1979)'}
# {'_id': 3648,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Abominable Snowman, The (1957)'}
# {'_id': 3658, 'genres': 'Sci-Fi', 'title': 'Quatermass and the Pit (1967)'}
# {'_id': 3659, 'genres': 'Sci-Fi|Thriller', 'title': 'Quatermass II (1957)'}
# {'_id': 3660,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master (1989)'}
# {'_id': 3662,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': "Puppet Master III: Toulon's Revenge (1991)"}
# {'_id': 3661,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master II (1990)'}
# {'_id': 3665,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Curse of the Puppet Master (1998)'}
# {'_id': 3664,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master 5: The Final Chapter (1994)'}
# {'_id': 3663,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master 4 (1993)'}
# {'_id': 3666,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Retro Puppetmaster (1999)'}
# {'_id': 3686, 'genres': 'Thriller', 'title': 'Flatliners (1990)'}
# {'_id': 3687, 'genres': 'Sci-Fi', 'title': 'Light Years (1988)'}
# {'_id': 3697, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Predator 2 (1990)'}
# {'_id': 3696,
#  'genres': 'Comedy|Horror|Sci-Fi',
#  'title': 'Night of the Creeps (1986)'}
# {'_id': 3699,
#  'genres': 'Adventure|Drama|Romance|Sci-Fi',
#  'title': 'Starman (1984)'}
# {'_id': 3698,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Running Man, The (1987)'}
# {'_id': 3701, 'genres': 'Crime|Drama|Sci-Fi', 'title': 'Alien Nation (1988)'}
# {'_id': 3700,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Brother from Another Planet, The (1984)'}
# {'_id': 3702, 'genres': 'Action|Sci-Fi', 'title': 'Mad Max (1979)'}
# {'_id': 3703,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Mad Max 2 (a.k.a. The Road Warrior) (1981)'}
# {'_id': 3704,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Mad Max Beyond Thunderdome (1985)'}
# {'_id': 3705,
#  'genres': 'Action|Adventure|Romance|Thriller',
#  'title': 'Bird on a Wire (1990)'}
# {'_id': 3706,
#  'genres': 'Film-Noir|Mystery|Thriller',
#  'title': 'Angel Heart (1987)'}
# {'_id': 3708, 'genres': 'Horror|Thriller', 'title': 'Firestarter (1984)'}
# {'_id': 3726,
#  'genres': 'Action|Thriller',
#  'title': 'Assault on Precinct 13 (1976)'}
# {'_id': 3728, 'genres': 'Thriller', 'title': 'One False Move (1991)'}
# {'_id': 3731, 'genres': 'Drama|Thriller', 'title': "Cutter's Way (1981)"}
# {'_id': 3745,
#  'genres': 'Adventure|Animation|Sci-Fi',
#  'title': 'Titan A.E. (2000)'}
# {'_id': 3755,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Perfect Storm, The (2000)'}
# {'_id': 3758, 'genres': 'Drama|Sci-Fi|Thriller', 'title': 'Communion (1989)'}
# {'_id': 3763, 'genres': 'Action|Crime|Thriller', 'title': 'F/X (1986)'}
# {'_id': 3764, 'genres': 'Action|Crime|Thriller', 'title': 'F/X 2 (1992)'}
# {'_id': 3770,
#  'genres': 'Adventure|Crime|Sci-Fi|Thriller',
#  'title': 'Dreamscape (1984)'}
# {'_id': 3779, 'genres': 'Sci-Fi', 'title': 'Project Moon Base (1953)'}
# {'_id': 3780, 'genres': 'Sci-Fi', 'title': 'Rocketship X-M (1950)'}
# {'_id': 3793, 'genres': 'Action|Sci-Fi', 'title': 'X-Men (2000)'}
# {'_id': 3797, 'genres': 'Thriller', 'title': 'In Crowd, The (2000)'}
# {'_id': 3796,
#  'genres': 'Romance|Thriller',
#  'title': 'Wisdom of Crocodiles, The (a.k.a. Immortality) (2000)'}
# {'_id': 3798, 'genres': 'Thriller', 'title': 'What Lies Beneath (2000)'}
# {'_id': 3802, 'genres': 'Action|Sci-Fi', 'title': 'Freejack (1992)'}
# {'_id': 3826, 'genres': 'Horror|Sci-Fi|Thriller', 'title': 'Hollow Man (2000)'}
# {'_id': 3827, 'genres': 'Action|Sci-Fi', 'title': 'Space Cowboys (2000)'}
# {'_id': 3830,
#  'genres': 'Comedy|Horror|Thriller',
#  'title': 'Psycho Beach Party (2000)'}
# {'_id': 3810, 'genres': 'Drama|Thriller', 'title': 'White Sands (1992)'}
# {'_id': 3833,
#  'genres': 'Horror|Sci-Fi',
#  'title': "Brain That Wouldn't Die, The (1962)"}
# {'_id': 3835, 'genres': 'Thriller', 'title': 'Crush, The (1993)'}
# {'_id': 3848, 'genres': 'Drama|Thriller', 'title': 'Silent Fall (1994)'}
# {'_id': 3849, 'genres': 'Thriller', 'title': 'Spiral Staircase, The (1946)'}
# {'_id': 3850,
#  'genres': 'Crime|Thriller',
#  'title': 'Whatever Happened to Aunt Alice? (1969)'}
# {'_id': 3857, 'genres': 'Thriller', 'title': 'Bless the Child (2000)'}
# {'_id': 3878, 'genres': 'Sci-Fi', 'title': 'X: The Unknown (1956)'}
# {'_id': 3863, 'genres': 'Sci-Fi|Thriller', 'title': 'Cell, The (2000)'}
# {'_id': 3864,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Godzilla 2000 (Gojira ni-sen mireniamu) (1999)'}
# {'_id': 3895, 'genres': 'Crime|Thriller', 'title': 'Watcher, The (2000)'}
# {'_id': 3896, 'genres': 'Crime|Thriller', 'title': 'Way of the Gun, The (2000)'}
# {'_id': 3923, 'genres': 'Horror|Sci-Fi', 'title': 'Return of the Fly (1959)'}
# {'_id': 3926,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'Voyage to the Bottom of the Sea (1961)'}
# {'_id': 3927, 'genres': 'Adventure|Sci-Fi', 'title': 'Fantastic Voyage (1966)'}
# {'_id': 3931,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Giant Gila Monster, The (1959)'}
# {'_id': 3932, 'genres': 'Horror|Sci-Fi', 'title': 'Invisible Man, The (1933)'}
# {'_id': 3934, 'genres': 'Sci-Fi', 'title': 'Kronos (1957)'}
# {'_id': 3933, 'genres': 'Horror|Sci-Fi', 'title': 'Killer Shrews, The (1959)'}
# {'_id': 3936,
#  'genres': 'Drama|Thriller',
#  'title': 'Phantom of the Opera, The (1943)'}
# {'_id': 3937, 'genres': 'Sci-Fi|Thriller', 'title': 'Runaway (1984)'}
# {'_id': 3893, 'genres': 'Comedy|Thriller', 'title': 'Nurse Betty (2000)'}
# {'_id': 3946, 'genres': 'Action|Drama|Thriller', 'title': 'Get Carter (2000)'}
# {'_id': 3947, 'genres': 'Thriller', 'title': 'Get Carter (1971)'}
# {'_id': 3952, 'genres': 'Drama|Thriller', 'title': 'Contender, The (2000)'}

# %% [markdown]
# **Q**: If we want more advanced textual search, we need a particular index. Use the `create_index()` method to index as [TEXT](https://docs.mongodb.com/manual/core/index-text/) the `genres` field of the `movies` collection.

# %%
movies.create_index({
    "genres" : "text"
})
# Out:
# 'genres_text'

# %% [markdown]
# **Q**: Restart the search for science fiction and thriller movies with the operator `$text`

# %%
# Find movies where the 'genres' property matches the regex pattern
science_fiction_and_suspense_movies = movies.find({
        "$text": {
            "$search": "Sci-Fi Thriller" 
        }
    }
)

# Display the results
for movie in science_fiction_and_suspense_movies:
    pprint(movie)
# Out:
# {'_id': 3934, 'genres': 'Sci-Fi', 'title': 'Kronos (1957)'}
# {'_id': 3878, 'genres': 'Sci-Fi', 'title': 'X: The Unknown (1956)'}
# {'_id': 3780, 'genres': 'Sci-Fi', 'title': 'Rocketship X-M (1950)'}
# {'_id': 3779, 'genres': 'Sci-Fi', 'title': 'Project Moon Base (1953)'}
# {'_id': 3687, 'genres': 'Sci-Fi', 'title': 'Light Years (1988)'}
# {'_id': 3658, 'genres': 'Sci-Fi', 'title': 'Quatermass and the Pit (1967)'}
# {'_id': 3486, 'genres': 'Sci-Fi', 'title': 'Devil Girl From Mars (1954)'}
# {'_id': 3375, 'genres': 'Sci-Fi', 'title': 'Destination Moon (1950)'}
# {'_id': 3354, 'genres': 'Sci-Fi', 'title': 'Mission to Mars (2000)'}
# {'_id': 3032, 'genres': 'Sci-Fi', 'title': 'Omega Man, The (1971)'}
# {'_id': 2698, 'genres': 'Sci-Fi', 'title': 'Zone 39 (1997)'}
# {'_id': 2665,
#  'genres': 'Sci-Fi',
#  'title': 'Earth Vs. the Flying Saucers (1956)'}
# {'_id': 2660,
#  'genres': 'Sci-Fi',
#  'title': 'Thing From Another World, The (1951)'}
# {'_id': 2667, 'genres': 'Sci-Fi', 'title': 'Mole People, The (1956)'}
# {'_id': 2666, 'genres': 'Sci-Fi', 'title': 'It Conquered the World (1956)'}
# {'_id': 2663,
#  'genres': 'Sci-Fi',
#  'title': 'It Came from Beneath the Sea (1955)'}
# {'_id': 2658, 'genres': 'Sci-Fi', 'title': 'Flying Saucer, The (1950)'}
# {'_id': 2661, 'genres': 'Sci-Fi', 'title': 'It Came from Outer Space (1953)'}
# {'_id': 2578, 'genres': 'Sci-Fi', 'title': 'Sticky Fingers of Time, The (1997)'}
# {'_id': 2526, 'genres': 'Sci-Fi', 'title': 'Meteor (1979)'}
# {'_id': 2034, 'genres': 'Sci-Fi', 'title': 'Black Hole, The (1979)'}
# {'_id': 2010, 'genres': 'Sci-Fi', 'title': 'Metropolis (1926)'}
# {'_id': 1570, 'genres': 'Sci-Fi', 'title': 'Tetsuo II: Body Hammer (1992)'}
# {'_id': 1301, 'genres': 'Sci-Fi', 'title': 'Forbidden Planet (1956)'}
# {'_id': 1206, 'genres': 'Sci-Fi', 'title': 'Clockwork Orange, A (1971)'}
# {'_id': 1199, 'genres': 'Sci-Fi', 'title': 'Brazil (1985)'}
# {'_id': 680, 'genres': 'Sci-Fi', 'title': 'Alphaville (1965)'}
# {'_id': 3937, 'genres': 'Sci-Fi|Thriller', 'title': 'Runaway (1984)'}
# {'_id': 3933, 'genres': 'Horror|Sci-Fi', 'title': 'Killer Shrews, The (1959)'}
# {'_id': 3932, 'genres': 'Horror|Sci-Fi', 'title': 'Invisible Man, The (1933)'}
# {'_id': 3931,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Giant Gila Monster, The (1959)'}
# {'_id': 3927, 'genres': 'Adventure|Sci-Fi', 'title': 'Fantastic Voyage (1966)'}
# {'_id': 3926,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'Voyage to the Bottom of the Sea (1961)'}
# {'_id': 3923, 'genres': 'Horror|Sci-Fi', 'title': 'Return of the Fly (1959)'}
# {'_id': 3863, 'genres': 'Sci-Fi|Thriller', 'title': 'Cell, The (2000)'}
# {'_id': 3833,
#  'genres': 'Horror|Sci-Fi',
#  'title': "Brain That Wouldn't Die, The (1962)"}
# {'_id': 3827, 'genres': 'Action|Sci-Fi', 'title': 'Space Cowboys (2000)'}
# {'_id': 3802, 'genres': 'Action|Sci-Fi', 'title': 'Freejack (1992)'}
# {'_id': 3793, 'genres': 'Action|Sci-Fi', 'title': 'X-Men (2000)'}
# {'_id': 3704,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Mad Max Beyond Thunderdome (1985)'}
# {'_id': 3703,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Mad Max 2 (a.k.a. The Road Warrior) (1981)'}
# {'_id': 3702, 'genres': 'Action|Sci-Fi', 'title': 'Mad Max (1979)'}
# {'_id': 3700,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Brother from Another Planet, The (1984)'}
# {'_id': 3659, 'genres': 'Sci-Fi|Thriller', 'title': 'Quatermass II (1957)'}
# {'_id': 3648,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Abominable Snowman, The (1957)'}
# {'_id': 3593, 'genres': 'Action|Sci-Fi', 'title': 'Battlefield Earth (2000)'}
# {'_id': 3592,
#  'genres': 'Animation|Sci-Fi',
#  'title': 'Time Masters (Les Ma�tres du Temps) (1982)'}
# {'_id': 3574,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Carnosaur 3: Primal Species (1996)'}
# {'_id': 3573, 'genres': 'Horror|Sci-Fi', 'title': 'Carnosaur 2 (1995)'}
# {'_id': 3572, 'genres': 'Horror|Sci-Fi', 'title': 'Carnosaur (1993)'}
# {'_id': 3503, 'genres': 'Drama|Sci-Fi', 'title': 'Solaris (Solyaris) (1972)'}
# {'_id': 3488,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Hideous Sun Demon, The (1959)'}
# {'_id': 3471,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Close Encounters of the Third Kind (1977)'}
# {'_id': 3474, 'genres': 'Sci-Fi|Thriller', 'title': 'Retroactive (1997)'}
# {'_id': 3464, 'genres': 'Sci-Fi|Thriller', 'title': 'Solar Crisis (1993)'}
# {'_id': 3401,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'Baby... Secret of the Lost Legend (1985)'}
# {'_id': 3340, 'genres': 'Horror|Sci-Fi', 'title': 'Bride of the Monster (1956)'}
# {'_id': 3326,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'What Planet Are You From? (2000)'}
# {'_id': 3300, 'genres': 'Action|Sci-Fi', 'title': 'Pitch Black (2000)'}
# {'_id': 3293, 'genres': 'Drama|Sci-Fi', 'title': 'Conceiving Ada (1997)'}
# {'_id': 3190, 'genres': 'Adventure|Sci-Fi', 'title': 'Supernova (2000)'}
# {'_id': 3080,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Goodbye, 20th Century (Zbogum na dvadesetiot vek) (1998)'}
# {'_id': 3058, 'genres': 'Horror|Sci-Fi', 'title': 'Ape, The (1940)'}
# {'_id': 3033, 'genres': 'Comedy|Sci-Fi', 'title': 'Spaceballs (1987)'}
# {'_id': 3024, 'genres': 'Horror|Sci-Fi', 'title': 'Piranha (1978)'}
# {'_id': 2900, 'genres': 'Horror|Sci-Fi', 'title': 'Monkey Shines (1988)'}
# {'_id': 2901, 'genres': 'Horror|Sci-Fi', 'title': 'Phantasm (1979)'}
# {'_id': 2827,
#  'genres': 'Sci-Fi|Thriller',
#  'title': "Astronaut's Wife, The (1999)"}
# {'_id': 2807,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Universal Soldier: The Return (1999)'}
# {'_id': 2808, 'genres': 'Action|Sci-Fi', 'title': 'Universal Soldier (1992)'}
# {'_id': 2668, 'genres': 'Horror|Sci-Fi', 'title': 'Swamp Thing (1982)'}
# {'_id': 2664,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Invasion of the Body Snatchers (1956)'}
# {'_id': 2656, 'genres': 'Horror|Sci-Fi', 'title': 'Tarantula (1955)'}
# {'_id': 2615,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'My Science Project (1985)'}
# {'_id': 2602,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'Mighty Peking Man (Hsing hsing wang) (1977)'}
# {'_id': 2549, 'genres': 'Action|Sci-Fi', 'title': 'Wing Commander (1999)'}
# {'_id': 2532,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Conquest of the Planet of the Apes (1972)'}
# {'_id': 2533,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Escape from the Planet of the Apes (1971)'}
# {'_id': 2530,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Beneath the Planet of the Apes (1970)'}
# {'_id': 2531,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Battle for the Planet of the Apes (1973)'}
# {'_id': 2529, 'genres': 'Action|Sci-Fi', 'title': 'Planet of the Apes (1968)'}
# {'_id': 2498, 'genres': 'Comedy|Sci-Fi', 'title': 'My Favorite Martian (1999)'}
# {'_id': 2495,
#  'genres': 'Animation|Sci-Fi',
#  'title': 'Fantastic Planet, The (La Plan�te sauvage) (1973)'}
# {'_id': 2455, 'genres': 'Horror|Sci-Fi', 'title': 'Fly, The (1986)'}
# {'_id': 2456, 'genres': 'Horror|Sci-Fi', 'title': 'Fly II, The (1989)'}
# {'_id': 2454, 'genres': 'Horror|Sci-Fi', 'title': 'Fly, The (1958)'}
# {'_id': 2448, 'genres': 'Horror|Sci-Fi', 'title': 'Virus (1999)'}
# {'_id': 2393,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Star Trek: Insurrection (1998)'}
# {'_id': 2428, 'genres': 'Horror|Sci-Fi', 'title': 'Faculty, The (1998)'}
# {'_id': 2408, 'genres': 'Comedy|Sci-Fi', 'title': 'Cocoon: The Return (1988)'}
# {'_id': 2407, 'genres': 'Comedy|Sci-Fi', 'title': 'Cocoon (1985)'}
# {'_id': 2377, 'genres': 'Horror|Sci-Fi', 'title': 'Lifeforce (1985)'}
# {'_id': 2365,
#  'genres': 'Action|Sci-Fi',
#  'title': 'King Kong vs. Godzilla (Kingukongu tai Gojira) (1962)'}
# {'_id': 2364, 'genres': 'Action|Sci-Fi', 'title': 'Godzilla (Gojira) (1984)'}
# {'_id': 2363, 'genres': 'Action|Sci-Fi', 'title': 'Godzilla (Gojira) (1954)'}
# {'_id': 2346,
#  'genres': 'Sci-Fi|Thriller',
#  'title': 'Stepford Wives, The (1975)'}
# {'_id': 2311, 'genres': 'Mystery|Sci-Fi', 'title': '2010 (1984)'}
# {'_id': 2256, 'genres': 'Horror|Sci-Fi', 'title': 'Parasite (1982)'}
# {'_id': 2232, 'genres': 'Sci-Fi|Thriller', 'title': 'Cube (1997)'}
# {'_id': 2117, 'genres': 'Drama|Sci-Fi', 'title': 'Nineteen Eighty-Four (1984)'}
# {'_id': 2091,
#  'genres': "Children's|Sci-Fi",
#  'title': 'Return from Witch Mountain (1978)'}
# {'_id': 2021, 'genres': 'Fantasy|Sci-Fi', 'title': 'Dune (1984)'}
# {'_id': 2009, 'genres': 'Sci-Fi|Thriller', 'title': 'Soylent Green (1973)'}
# {'_id': 2011,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'Back to the Future Part II (1989)'}
# {'_id': 1965, 'genres': 'Comedy|Sci-Fi', 'title': 'Repo Man (1984)'}
# {'_id': 1921, 'genres': 'Sci-Fi|Thriller', 'title': 'Pi (1998)'}
# {'_id': 1924,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Plan 9 from Outer Space (1958)'}
# {'_id': 1882, 'genres': 'Action|Sci-Fi', 'title': 'Godzilla (1998)'}
# {'_id': 1862, 'genres': 'Horror|Sci-Fi', 'title': 'Species II (1998)'}
# {'_id': 1692, 'genres': 'Horror|Sci-Fi', 'title': 'Alien Escape (1995)'}
# {'_id': 1603, 'genres': 'Sci-Fi|Thriller', 'title': 'Mimic (1997)'}
# {'_id': 1584, 'genres': 'Drama|Sci-Fi', 'title': 'Contact (1997)'}
# {'_id': 1527, 'genres': 'Action|Sci-Fi', 'title': 'Fifth Element, The (1997)'}
# {'_id': 1383,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Adrenalin: Fear the Rush (1996)'}
# {'_id': 1334, 'genres': 'Horror|Sci-Fi', 'title': 'Blob, The (1958)'}
# {'_id': 1306,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Until the End of the World (Bis ans Ende der Welt) (1991)'}
# {'_id': 1270, 'genres': 'Comedy|Sci-Fi', 'title': 'Back to the Future (1985)'}
# {'_id': 1253,
#  'genres': 'Drama|Sci-Fi',
#  'title': 'Day the Earth Stood Still, The (1951)'}
# {'_id': 1232, 'genres': 'Mystery|Sci-Fi', 'title': 'Stalker (1979)'}
# {'_id': 1175, 'genres': 'Comedy|Sci-Fi', 'title': 'Delicatessen (1991)'}
# {'_id': 1077, 'genres': 'Comedy|Sci-Fi', 'title': 'Sleeper (1973)'}
# {'_id': 968,
#  'genres': 'Horror|Sci-Fi',
#  'title': 'Night of the Living Dead (1968)'}
# {'_id': 880,
#  'genres': 'Sci-Fi|Thriller',
#  'title': 'Island of Dr. Moreau, The (1996)'}
# {'_id': 750,
#  'genres': 'Sci-Fi|War',
#  'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the '
#           'Bomb (1963)'}
# {'_id': 741,
#  'genres': 'Animation|Sci-Fi',
#  'title': 'Ghost in the Shell (Kokaku kidotai) (1995)'}
# {'_id': 737, 'genres': 'Action|Sci-Fi', 'title': 'Barb Wire (1996)'}
# {'_id': 718,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'Visitors, The (Les Visiteurs) (1993)'}
# {'_id': 674, 'genres': 'Adventure|Sci-Fi', 'title': 'Barbarella (1968)'}
# {'_id': 671,
#  'genres': 'Comedy|Sci-Fi',
#  'title': 'Mystery Science Theater 3000: The Movie (1996)'}
# {'_id': 519, 'genres': 'Sci-Fi|Thriller', 'title': 'Robocop 3 (1993)'}
# {'_id': 512,
#  'genres': 'Horror|Sci-Fi',
#  'title': "Robert A. Heinlein's The Puppet Masters (1994)"}
# {'_id': 504, 'genres': 'Action|Sci-Fi', 'title': 'No Escape (1994)'}
# {'_id': 442, 'genres': 'Action|Sci-Fi', 'title': 'Demolition Man (1993)'}
# {'_id': 435, 'genres': 'Comedy|Sci-Fi', 'title': 'Coneheads (1993)'}
# {'_id': 405,
#  'genres': 'Action|Sci-Fi',
#  'title': 'Highlander III: The Sorcerer (1994)'}
# {'_id': 379, 'genres': 'Action|Sci-Fi', 'title': 'Timecop (1994)'}
# {'_id': 338, 'genres': 'Sci-Fi|Thriller', 'title': 'Virtuosity (1995)'}
# {'_id': 332, 'genres': 'Horror|Sci-Fi', 'title': 'Village of the Damned (1995)'}
# {'_id': 256, 'genres': 'Comedy|Sci-Fi', 'title': 'Junior (1994)'}
# {'_id': 196, 'genres': 'Horror|Sci-Fi', 'title': 'Species (1995)'}
# {'_id': 185, 'genres': 'Sci-Fi|Thriller', 'title': 'Net, The (1995)'}
# {'_id': 76, 'genres': 'Sci-Fi|Thriller', 'title': 'Screamers (1995)'}
# {'_id': 66,
#  'genres': 'Sci-Fi|Thriller',
#  'title': 'Lawnmower Man 2: Beyond Cyberspace (1996)'}
# {'_id': 32, 'genres': 'Drama|Sci-Fi', 'title': 'Twelve Monkeys (1995)'}
# {'_id': 29,
#  'genres': 'Adventure|Sci-Fi',
#  'title': 'City of Lost Children, The (1995)'}
# {'_id': 24, 'genres': 'Drama|Sci-Fi', 'title': 'Powder (1995)'}
# {'_id': 3864,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Godzilla 2000 (Gojira ni-sen mireniamu) (1999)'}
# {'_id': 3826, 'genres': 'Horror|Sci-Fi|Thriller', 'title': 'Hollow Man (2000)'}
# {'_id': 3758, 'genres': 'Drama|Sci-Fi|Thriller', 'title': 'Communion (1989)'}
# {'_id': 3745,
#  'genres': 'Adventure|Animation|Sci-Fi',
#  'title': 'Titan A.E. (2000)'}
# {'_id': 3701, 'genres': 'Crime|Drama|Sci-Fi', 'title': 'Alien Nation (1988)'}
# {'_id': 3698,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Running Man, The (1987)'}
# {'_id': 3696,
#  'genres': 'Comedy|Horror|Sci-Fi',
#  'title': 'Night of the Creeps (1986)'}
# {'_id': 3697, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Predator 2 (1990)'}
# {'_id': 3666,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Retro Puppetmaster (1999)'}
# {'_id': 3663,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master 4 (1993)'}
# {'_id': 3664,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master 5: The Final Chapter (1994)'}
# {'_id': 3665,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Curse of the Puppet Master (1998)'}
# {'_id': 3661,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master II (1990)'}
# {'_id': 3662,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': "Puppet Master III: Toulon's Revenge (1991)"}
# {'_id': 3660,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Puppet Master (1989)'}
# {'_id': 3638, 'genres': 'Action|Romance|Sci-Fi', 'title': 'Moonraker (1979)'}
# {'_id': 3576, 'genres': 'Action|Horror|Sci-Fi', 'title': 'Hidden, The (1987)'}
# {'_id': 3527, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Predator (1987)'}
# {'_id': 3417,
#  'genres': 'Adventure|Comedy|Sci-Fi',
#  'title': 'Crimson Pirate, The (1952)'}
# {'_id': 3269,
#  'genres': 'Adventure|Romance|Sci-Fi',
#  'title': 'Forever Young (1992)'}
# {'_id': 3156,
#  'genres': 'Comedy|Drama|Sci-Fi',
#  'title': 'Bicentennial Man (1999)'}
# {'_id': 3175,
#  'genres': 'Adventure|Comedy|Sci-Fi',
#  'title': 'Galaxy Quest (1999)'}
# {'_id': 3070,
#  'genres': 'Adventure|Comedy|Sci-Fi',
#  'title': 'Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)'}
# {'_id': 2986, 'genres': 'Action|Crime|Sci-Fi', 'title': 'Robocop 2 (1990)'}
# {'_id': 2985, 'genres': 'Action|Crime|Sci-Fi', 'title': 'Robocop (1987)'}
# {'_id': 2968,
#  'genres': 'Adventure|Fantasy|Sci-Fi',
#  'title': 'Time Bandits (1981)'}
# {'_id': 2851, 'genres': 'Adventure|Sci-Fi|Thriller', 'title': 'Saturn 3 (1979)'}
# {'_id': 2722,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Deep Blue Sea (1999)'}
# {'_id': 2701,
#  'genres': 'Action|Sci-Fi|Western',
#  'title': 'Wild Wild West (1999)'}
# {'_id': 2681,
#  'genres': 'Comedy|Romance|Sci-Fi',
#  'title': 'Free Enterprise (1998)'}
# {'_id': 2672,
#  'genres': 'Drama|Sci-Fi|Thriller',
#  'title': 'Thirteenth Floor, The (1999)'}
# {'_id': 2662,
#  'genres': 'Action|Sci-Fi|War',
#  'title': 'War of the Worlds, The (1953)'}
# {'_id': 2642,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Superman III (1983)'}
# {'_id': 2643,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Superman IV: The Quest for Peace (1987)'}
# {'_id': 2641,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Superman II (1980)'}
# {'_id': 2640, 'genres': 'Action|Adventure|Sci-Fi', 'title': 'Superman (1978)'}
# {'_id': 2613,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Night of the Comet (1984)'}
# {'_id': 2614,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Chopping Mall (a.k.a. Killbots) (1986)'}
# {'_id': 2600, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'eXistenZ (1999)'}
# {'_id': 2594,
#  'genres': 'Drama|Romance|Sci-Fi',
#  'title': 'Open Your Eyes (Abre los ojos) (1997)'}
# {'_id': 2571, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Matrix, The (1999)'}
# {'_id': 2554,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Children of the Damned (1963)'}
# {'_id': 2553,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Village of the Damned (1960)'}
# {'_id': 2528,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': "Logan's Run (1976)"}
# {'_id': 2525, 'genres': 'Action|Horror|Sci-Fi', 'title': 'Alligator (1980)'}
# {'_id': 2450,
#  'genres': "Adventure|Children's|Sci-Fi",
#  'title': 'Howard the Duck (1986)'}
# {'_id': 2287, 'genres': 'Sci-Fi|Thriller|War', 'title': 'Them! (1954)'}
# {'_id': 2275,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Six-String Samurai (1998)'}
# {'_id': 2173,
#  'genres': 'Adventure|Fantasy|Sci-Fi',
#  'title': 'Navigator: A Mediaeval Odyssey, The (1988)'}
# {'_id': 2140,
#  'genres': "Children's|Fantasy|Sci-Fi",
#  'title': 'Dark Crystal, The (1982)'}
# {'_id': 2094,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Rocketeer, The (1991)'}
# {'_id': 2046,
#  'genres': "Adventure|Children's|Sci-Fi",
#  'title': 'Flight of the Navigator (1986)'}
# {'_id': 2053,
#  'genres': "Children's|Comedy|Sci-Fi",
#  'title': 'Honey, I Blew Up the Kid (1992)'}
# {'_id': 2038,
#  'genres': "Children's|Comedy|Sci-Fi",
#  'title': 'Cat from Outer Space, The (1978)'}
# {'_id': 2012,
#  'genres': 'Comedy|Sci-Fi|Western',
#  'title': 'Back to the Future Part III (1990)'}
# {'_id': 1909,
#  'genres': 'Mystery|Sci-Fi|Thriller',
#  'title': 'X-Files: Fight the Future, The (1998)'}
# {'_id': 1831,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Lost in Space (1998)'}
# {'_id': 1779, 'genres': 'Adventure|Sci-Fi|Thriller', 'title': 'Sphere (1998)'}
# {'_id': 1762, 'genres': 'Action|Horror|Sci-Fi', 'title': 'Deep Rising (1998)'}
# {'_id': 1720,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Time Tracers (1995)'}
# {'_id': 1690,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Alien: Resurrection (1997)'}
# {'_id': 1653, 'genres': 'Drama|Sci-Fi|Thriller', 'title': 'Gattaca (1997)'}
# {'_id': 1573, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Face/Off (1997)'}
# {'_id': 1396, 'genres': 'Crime|Drama|Sci-Fi', 'title': 'Sneakers (1992)'}
# {'_id': 1376,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek IV: The Voyage Home (1986)'}
# {'_id': 1371,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: The Motion Picture (1979)'}
# {'_id': 1375,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek III: The Search for Spock (1984)'}
# {'_id': 1374,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: The Wrath of Khan (1982)'}
# {'_id': 1373,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek V: The Final Frontier (1989)'}
# {'_id': 1372,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek VI: The Undiscovered Country (1991)'}
# {'_id': 1356,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: First Contact (1996)'}
# {'_id': 1240,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Terminator, The (1984)'}
# {'_id': 1037,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Lawnmower Man, The (1992)'}
# {'_id': 780,
#  'genres': 'Action|Sci-Fi|War',
#  'title': 'Independence Day (ID4) (1996)'}
# {'_id': 748, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Arrival, The (1996)'}
# {'_id': 692, 'genres': 'Action|Sci-Fi|Thriller', 'title': 'Solo (1996)'}
# {'_id': 611,
#  'genres': 'Action|Horror|Sci-Fi',
#  'title': 'Hellraiser: Bloodline (1996)'}
# {'_id': 589,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Terminator 2: Judgment Day (1991)'}
# {'_id': 541, 'genres': 'Film-Noir|Sci-Fi', 'title': 'Blade Runner (1982)'}
# {'_id': 480,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Jurassic Park (1993)'}
# {'_id': 426,
#  'genres': 'Horror|Sci-Fi|Thriller',
#  'title': 'Body Snatchers (1993)'}
# {'_id': 329,
#  'genres': 'Action|Adventure|Sci-Fi',
#  'title': 'Star Trek: Generations (1994)'}
# {'_id': 316, 'genres': 'Action|Adventure|Sci-Fi', 'title': 'Stargate (1994)'}
# {'_id': 286,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Nemesis 2: Nebula (1995)'}
# {'_id': 198, 'genres': 'Action|Crime|Sci-Fi', 'title': 'Strange Days (1995)'}
# {'_id': 173, 'genres': 'Action|Adventure|Sci-Fi', 'title': 'Judge Dredd (1995)'}
# {'_id': 172,
#  'genres': 'Action|Sci-Fi|Thriller',
#  'title': 'Johnny Mnemonic (1995)'}
# {'_id': 3770,
#  'genres': 'Adventure|Crime|Sci-Fi|Thriller',
#  'title': 'Dreamscape (1984)'}
# {'_id': 3699,
#  'genres': 'Adventure|Drama|Romance|Sci-Fi',
#  'title': 'Starman (1984)'}
# {'_id': 2916,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Total Recall (1990)'}
# {'_id': 2699,
#  'genres': 'Action|Comedy|Sci-Fi|Thriller',
#  'title': 'Arachnophobia (1990)'}
# {'_id': 2657,
#  'genres': 'Comedy|Horror|Musical|Sci-Fi',
#  'title': 'Rocky Horror Picture Show, The (1975)'}
# {'_id': 2628,
#  'genres': 'Action|Adventure|Fantasy|Sci-Fi',
#  'title': 'Star Wars: Episode I - The Phantom Menace (1999)'}
# {'_id': 2527,
#  'genres': 'Action|Sci-Fi|Thriller|Western',
#  'title': 'Westworld (1973)'}
# {'_id': 2288,
#  'genres': 'Action|Horror|Sci-Fi|Thriller',
#  'title': 'Thing, The (1982)'}
# {'_id': 2116,
#  'genres': "Adventure|Animation|Children's|Sci-Fi",
#  'title': 'Lord of the Rings, The (1978)'}
# {'_id': 2105,
#  'genres': 'Action|Adventure|Fantasy|Sci-Fi',
#  'title': 'Tron (1982)'}
# {'_id': 2093,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': 'Return to Oz (1985)'}
# {'_id': 1917,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Armageddon (1998)'}
# {'_id': 1876,
#  'genres': 'Action|Drama|Sci-Fi|Thriller',
#  'title': 'Deep Impact (1998)'}
# {'_id': 1750,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': 'Star Kid (1997)'}
# {'_id': 1748,
#  'genres': 'Film-Noir|Sci-Fi|Thriller',
#  'title': 'Dark City (1998)'}
# {'_id': 1676,
#  'genres': 'Action|Adventure|Sci-Fi|War',
#  'title': 'Starship Troopers (1997)'}
# {'_id': 1591,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Spawn (1997)'}
# {'_id': 1590,
#  'genres': 'Action|Mystery|Sci-Fi|Thriller',
#  'title': 'Event Horizon (1997)'}
# {'_id': 1580,
#  'genres': 'Action|Adventure|Comedy|Sci-Fi',
#  'title': 'Men in Black (1997)'}
# {'_id': 1544,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Lost World: Jurassic Park, The (1997)'}
# {'_id': 1391,
#  'genres': 'Action|Comedy|Sci-Fi|War',
#  'title': 'Mars Attacks! (1996)'}
# {'_id': 1320,
#  'genres': 'Action|Horror|Sci-Fi|Thriller',
#  'title': 'Alien� (1992)'}
# {'_id': 1274,
#  'genres': 'Adventure|Animation|Sci-Fi|Thriller',
#  'title': 'Akira (1988)'}
# {'_id': 1214,
#  'genres': 'Action|Horror|Sci-Fi|Thriller',
#  'title': 'Alien (1979)'}
# {'_id': 1200, 'genres': 'Action|Sci-Fi|Thriller|War', 'title': 'Aliens (1986)'}
# {'_id': 1129,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Escape from New York (1981)'}
# {'_id': 1127,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Abyss, The (1989)'}
# {'_id': 1097,
#  'genres': "Children's|Drama|Fantasy|Sci-Fi",
#  'title': 'E.T. the Extra-Terrestrial (1982)'}
# {'_id': 1019,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': '20,000 Leagues Under the Sea (1954)'}
# {'_id': 924,
#  'genres': 'Drama|Mystery|Sci-Fi|Thriller',
#  'title': '2001: A Space Odyssey (1968)'}
# {'_id': 849,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller',
#  'title': 'Escape from L.A. (1996)'}
# {'_id': 788,
#  'genres': 'Comedy|Fantasy|Romance|Sci-Fi',
#  'title': 'Nutty Professor, The (1996)'}
# {'_id': 546,
#  'genres': "Action|Adventure|Children's|Sci-Fi",
#  'title': 'Super Mario Bros. (1993)'}
# {'_id': 327,
#  'genres': 'Action|Comedy|Musical|Sci-Fi',
#  'title': 'Tank Girl (1995)'}
# {'_id': 260,
#  'genres': 'Action|Adventure|Fantasy|Sci-Fi',
#  'title': 'Star Wars: Episode IV - A New Hope (1977)'}
# {'_id': 160,
#  'genres': 'Action|Adventure|Mystery|Sci-Fi',
#  'title': 'Congo (1995)'}
# {'_id': 2322,
#  'genres': 'Action|Adventure|Sci-Fi|Thriller|War',
#  'title': 'Soldier (1998)'}
# {'_id': 2054,
#  'genres': "Adventure|Children's|Comedy|Fantasy|Sci-Fi",
#  'title': 'Honey, I Shrunk the Kids (1989)'}
# {'_id': 1215,
#  'genres': 'Action|Adventure|Comedy|Horror|Sci-Fi',
#  'title': 'Army of Darkness (1993)'}
# {'_id': 1210,
#  'genres': 'Action|Adventure|Romance|Sci-Fi|War',
#  'title': 'Star Wars: Episode VI - Return of the Jedi (1983)'}
# {'_id': 1196,
#  'genres': 'Action|Adventure|Drama|Sci-Fi|War',
#  'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)'}
# {'_id': 610,
#  'genres': 'Action|Adventure|Animation|Horror|Sci-Fi',
#  'title': 'Heavy Metal (1981)'}
# {'_id': 1205,
#  'genres': "Action|Animation|Children's|Sci-Fi|Thriller|War",
#  'title': 'Transformers: The Movie, The (1986)'}
# {'_id': 3947, 'genres': 'Thriller', 'title': 'Get Carter (1971)'}
# {'_id': 3857, 'genres': 'Thriller', 'title': 'Bless the Child (2000)'}
# {'_id': 3849, 'genres': 'Thriller', 'title': 'Spiral Staircase, The (1946)'}
# {'_id': 3835, 'genres': 'Thriller', 'title': 'Crush, The (1993)'}
# {'_id': 3798, 'genres': 'Thriller', 'title': 'What Lies Beneath (2000)'}
# {'_id': 3797, 'genres': 'Thriller', 'title': 'In Crowd, The (2000)'}
# {'_id': 3728, 'genres': 'Thriller', 'title': 'One False Move (1991)'}
# {'_id': 3686, 'genres': 'Thriller', 'title': 'Flatliners (1990)'}
# {'_id': 3634, 'genres': 'Thriller', 'title': 'Seven Days in May (1964)'}
# {'_id': 3557, 'genres': 'Thriller', 'title': 'Jennifer 8 (1992)'}
# {'_id': 3551, 'genres': 'Thriller', 'title': 'Marathon Man (1976)'}
# {'_id': 3505, 'genres': 'Thriller', 'title': 'No Way Out (1987)'}
# {'_id': 3484, 'genres': 'Thriller', 'title': 'Skulls, The (2000)'}
# {'_id': 3318, 'genres': 'Thriller', 'title': 'Deterrence (1998)'}
# {'_id': 3355, 'genres': 'Thriller', 'title': 'Ninth Gate, The (2000)'}
# {'_id': 3291, 'genres': 'Thriller', 'title': 'Trois (2000)'}
# {'_id': 3249,
#  'genres': 'Thriller',
#  'title': 'Hand That Rocks the Cradle, The (1992)'}
# {'_id': 3238, 'genres': 'Thriller', 'title': 'Eye of the Beholder (1999)'}
# {'_id': 3230, 'genres': 'Thriller', 'title': 'Odessa File, The (1974)'}
# {'_id': 3219, 'genres': 'Thriller', 'title': 'Pacific Heights (1990)'}
# {'_id': 3203, 'genres': 'Thriller', 'title': 'Dead Calm (1989)'}
# {'_id': 3204, 'genres': 'Thriller', 'title': 'Boys from Brazil, The (1978)'}
# {'_id': 3102, 'genres': 'Thriller', 'title': 'Jagged Edge (1985)'}
# {'_id': 3101, 'genres': 'Thriller', 'title': 'Fatal Attraction (1987)'}
# {'_id': 3075, 'genres': 'Thriller', 'title': 'Repulsion (1965)'}
# {'_id': 3063, 'genres': 'Thriller', 'title': 'Poison Ivy (1992)'}
# {'_id': 3064, 'genres': 'Thriller', 'title': 'Poison Ivy: New Seduction (1997)'}
# {'_id': 3055, 'genres': 'Thriller', 'title': "Felicia's Journey (1999)"}
# {'_id': 3056, 'genres': 'Thriller', 'title': 'Oxygen (1999)'}
# {'_id': 3015, 'genres': 'Thriller', 'title': 'Coma (1978)'}
# {'_id': 3008, 'genres': 'Thriller', 'title': 'Last Night (1998)'}
# {'_id': 3005, 'genres': 'Thriller', 'title': 'Bone Collector, The (1999)'}
# {'_id': 2983, 'genres': 'Thriller', 'title': 'Ipcress File, The (1965)'}
# {'_id': 2856, 'genres': 'Thriller', 'title': 'I Saw What You Did (1965)'}
# {'_id': 2841, 'genres': 'Thriller', 'title': 'Stir of Echoes (1999)'}
# {'_id': 2840, 'genres': 'Thriller', 'title': 'Stigmata (1999)'}
# {'_id': 2819, 'genres': 'Thriller', 'title': 'Three Days of the Condor (1975)'}
# {'_id': 2803, 'genres': 'Thriller', 'title': 'Pelican Brief, The (1993)'}
# {'_id': 2778, 'genres': 'Thriller', 'title': 'Never Talk to Strangers (1995)'}
# {'_id': 2762, 'genres': 'Thriller', 'title': 'Sixth Sense, The (1999)'}
# {'_id': 2753, 'genres': 'Thriller', 'title': 'Bedroom Window, The (1987)'}
# {'_id': 2707, 'genres': 'Thriller', 'title': 'Arlington Road (1999)'}
# {'_id': 2608, 'genres': 'Thriller', 'title': 'Heaven (1998)'}
# {'_id': 2505, 'genres': 'Thriller', 'title': '8MM (1999)'}
# {'_id': 2446, 'genres': 'Thriller', 'title': 'In Dreams (1999)'}
# {'_id': 2298, 'genres': 'Thriller', 'title': 'Strangeland (1998)'}
# {'_id': 2263, 'genres': 'Thriller', 'title': 'Seventh Sign, The (1988)'}
# {'_id': 2221, 'genres': 'Thriller', 'title': 'Blackmail (1929)'}
# {'_id': 2227, 'genres': 'Thriller', 'title': 'Lodger, The (1926)'}
# {'_id': 2214, 'genres': 'Thriller', 'title': 'Number Seventeen (1932)'}
# {'_id': 2210, 'genres': 'Thriller', 'title': 'Sabotage (1936)'}
# {'_id': 2212,
#  'genres': 'Thriller',
#  'title': 'Man Who Knew Too Much, The (1934)'}
# {'_id': 2211, 'genres': 'Thriller', 'title': 'Secret Agent (1936)'}
# {'_id': 2204, 'genres': 'Thriller', 'title': 'Saboteur (1942)'}
# {'_id': 2183,
#  'genres': 'Thriller',
#  'title': 'Man Who Knew Too Much, The (1956)'}
# {'_id': 2185, 'genres': 'Thriller', 'title': 'I Confess (1953)'}
# {'_id': 2179, 'genres': 'Thriller', 'title': 'Topaz (1969)'}
# {'_id': 2181, 'genres': 'Thriller', 'title': 'Marnie (1964)'}
# {'_id': 2180, 'genres': 'Thriller', 'title': 'Torn Curtain (1966)'}
# {'_id': 2178, 'genres': 'Thriller', 'title': 'Frenzy (1972)'}
# {'_id': 2176, 'genres': 'Thriller', 'title': 'Rope (1948)'}
# {'_id': 1889, 'genres': 'Thriller', 'title': 'Insomnia (1997)'}
# {'_id': 1798, 'genres': 'Thriller', 'title': 'Hush (1998)'}
# {'_id': 1718, 'genres': 'Thriller', 'title': 'Stranger in the House (1997)'}
# {'_id': 1715, 'genres': 'Thriller', 'title': 'Office Killer (1997)'}
# {'_id': 1709, 'genres': 'Thriller', 'title': 'Legal Deceit (1997)'}
# {'_id': 1661, 'genres': 'Thriller', 'title': 'Switchback (1997)'}
# {'_id': 1631, 'genres': 'Thriller', 'title': 'Assignment, The (1997)'}
# {'_id': 1430, 'genres': 'Thriller', 'title': 'Underworld (1997)'}
# {'_id': 1427, 'genres': 'Thriller', 'title': 'Turbulence (1997)'}
# {'_id': 1343, 'genres': 'Thriller', 'title': 'Cape Fear (1991)'}
# {'_id': 1249, 'genres': 'Thriller', 'title': 'Nikita (La Femme Nikita) (1990)'}
# {'_id': 1076, 'genres': 'Thriller', 'title': 'Innocents, The (1961)'}
# {'_id': 1055, 'genres': 'Thriller', 'title': 'Shadow Conspiracy (1997)'}
# {'_id': 992, 'genres': 'Thriller', 'title': "Rich Man's Wife, The (1996)"}
# {'_id': 965, 'genres': 'Thriller', 'title': '39 Steps, The (1935)'}
# {'_id': 929, 'genres': 'Thriller', 'title': 'Foreign Correspondent (1940)'}
# {'_id': 890, 'genres': 'Thriller', 'title': 'Baton Rouge (1988)'}
# {'_id': 782, 'genres': 'Thriller', 'title': 'Fan, The (1996)'}
# {'_id': 696, 'genres': 'Thriller', 'title': 'Butterfly Kiss (1995)'}
# {'_id': 662, 'genres': 'Thriller', 'title': 'Fear (1996)'}
# {'_id': 600, 'genres': 'Thriller', 'title': 'Love and a .45 (1994)'}
# {'_id': 579, 'genres': 'Thriller', 'title': 'Scorta, La (1993)'}
# {'_id': 561, 'genres': 'Thriller', 'title': 'Killer (Bulletproof Heart) (1994)'}
# {'_id': 554, 'genres': 'Thriller', 'title': 'Trial by Jury (1994)'}
# {'_id': 540, 'genres': 'Thriller', 'title': 'Sliver (1993)'}
# {'_id': 490, 'genres': 'Thriller', 'title': 'Malice (1993)'}
# {'_id': 482, 'genres': 'Thriller', 'title': 'Killing Zoe (1994)'}
# {'_id': 422, 'genres': 'Thriller', 'title': 'Blink (1994)'}
# {'_id': 373, 'genres': 'Thriller', 'title': 'Red Rock West (1992)'}
# {'_id': 319, 'genres': 'Thriller', 'title': 'Shallow Grave (1994)'}
# {'_id': 291, 'genres': 'Thriller', 'title': 'Poison Ivy II (1995)'}
# {'_id': 240, 'genres': 'Thriller', 'title': 'Hideaway (1995)'}
# {'_id': 226, 'genres': 'Thriller', 'title': 'Dream Man (1995)'}
# {'_id': 200, 'genres': 'Thriller', 'title': 'Tie That Binds, The (1995)'}
# {'_id': 190, 'genres': 'Thriller', 'title': 'Safe (1995)'}
# {'_id': 183, 'genres': 'Thriller', 'title': 'Mute Witness (1994)'}
# {'_id': 132, 'genres': 'Thriller', 'title': 'Jade (1995)'}
# {'_id': 103, 'genres': 'Thriller', 'title': 'Unforgettable (1996)'}
# {'_id': 23, 'genres': 'Thriller', 'title': 'Assassins (1995)'}
# {'_id': 18, 'genres': 'Thriller', 'title': 'Four Rooms (1995)'}
# {'_id': 3952, 'genres': 'Drama|Thriller', 'title': 'Contender, The (2000)'}
# {'_id': 3893, 'genres': 'Comedy|Thriller', 'title': 'Nurse Betty (2000)'}
# {'_id': 3936,
#  'genres': 'Drama|Thriller',
#  'title': 'Phantom of the Opera, The (1943)'}
# {'_id': 3896, 'genres': 'Crime|Thriller', 'title': 'Way of the Gun, The (2000)'}
# {'_id': 3895, 'genres': 'Crime|Thriller', 'title': 'Watcher, The (2000)'}
# {'_id': 3850,
#  'genres': 'Crime|Thriller',
#  'title': 'Whatever Happened to Aunt Alice? (1969)'}
# {'_id': 3848, 'genres': 'Drama|Thriller', 'title': 'Silent Fall (1994)'}
# {'_id': 3810, 'genres': 'Drama|Thriller', 'title': 'White Sands (1992)'}
# {'_id': 3796,
#  'genres': 'Romance|Thriller',
#  'title': 'Wisdom of Crocodiles, The (a.k.a. Immortality) (2000)'}
# {'_id': 3731, 'genres': 'Drama|Thriller', 'title': "Cutter's Way (1981)"}
# {'_id': 3726,
#  'genres': 'Action|Thriller',
#  'title': 'Assault on Precinct 13 (1976)'}
# {'_id': 3708, 'genres': 'Horror|Thriller', 'title': 'Firestarter (1984)'}
# {'_id': 3627, 'genres': 'Horror|Thriller', 'title': 'Carnival of Souls (1962)'}
# {'_id': 3623,
#  'genres': 'Action|Thriller',
#  'title': 'Mission: Impossible 2 (2000)'}
# {'_id': 3555, 'genres': 'Action|Thriller', 'title': 'U-571 (2000)'}
# {'_id': 3553, 'genres': 'Drama|Thriller', 'title': 'Gossip (2000)'}
# {'_id': 3546,
#  'genres': 'Drama|Thriller',
#  'title': 'What Ever Happened to Baby Jane? (1962)'}
# {'_id': 3540, 'genres': 'Romance|Thriller', 'title': 'Passion of Mind (1999)'}
# {'_id': 3529,
#  'genres': 'Crime|Thriller',
#  'title': 'Postman Always Rings Twice, The (1981)'}
# {'_id': 3523, 'genres': 'Action|Thriller', 'title': 'Taffin (1988)'}
# {'_id': 3518,
#  'genres': 'Drama|Thriller',
#  'title': 'End of Violence, The (1997)'}
# {'_id': 3513, 'genres': 'Drama|Thriller', 'title': 'Rules of Engagement (2000)'}
# {'_id': 3510, 'genres': 'Drama|Thriller', 'title': 'Frequency (2000)'}
# {'_id': 3455, 'genres': 'Drama|Thriller', 'title': 'Buddy Boy (1999)'}
# {'_id': 3445,
#  'genres': 'Mystery|Thriller',
#  'title': 'Eyes of Laura Mars (1978)'}
# {'_id': 3409, 'genres': 'Drama|Thriller', 'title': 'Final Destination (2000)'}
# {'_id': 3403, 'genres': 'Drama|Thriller', 'title': 'Raise the Titanic (1980)'}
# {'_id': 3420,
#  'genres': 'Drama|Thriller',
#  'title': '...And Justice for All (1979)'}
# {'_id': 3370, 'genres': 'Drama|Thriller', 'title': 'Betrayed (1988)'}
# {'_id': 3348, 'genres': 'Crime|Thriller', 'title': 'Night Visitor, The (1970)'}
# {'_id': 3316, 'genres': 'Action|Thriller', 'title': 'Reindeer Games (2000)'}
# {'_id': 3256, 'genres': 'Action|Thriller', 'title': 'Patriot Games (1992)'}
# {'_id': 3267, 'genres': 'Action|Thriller', 'title': 'Mariachi, El (1992)'}
# {'_id': 3147, 'genres': 'Drama|Thriller', 'title': 'Green Mile, The (1999)'}
# {'_id': 3113, 'genres': 'Action|Thriller', 'title': 'End of Days (1999)'}
# {'_id': 3082,
#  'genres': 'Action|Thriller',
#  'title': 'World Is Not Enough, The (1999)'}
# {'_id': 2992, 'genres': 'Horror|Thriller', 'title': 'Rawhead Rex (1986)'}
# {'_id': 2982, 'genres': 'Horror|Thriller', 'title': 'Guardian, The (1990)'}
# {'_id': 2974, 'genres': 'Horror|Thriller', 'title': 'Bats (1999)'}
# {'_id': 2967, 'genres': 'Drama|Thriller', 'title': 'Bad Seed, The (1956)'}
# {'_id': 2952,
#  'genres': 'Crime|Thriller',
#  'title': 'Hard 8 (a.k.a. Sydney, a.k.a. Hard Eight) (1996)'}
# {'_id': 2939, 'genres': 'Drama|Thriller', 'title': 'Niagara (1953)'}
# {'_id': 2917, 'genres': 'Crime|Thriller', 'title': 'Body Heat (1981)'}
# {'_id': 2903, 'genres': 'Horror|Thriller', 'title': 'Psycho III (1986)'}
# {'_id': 2902, 'genres': 'Horror|Thriller', 'title': 'Psycho II (1983)'}
# {'_id': 2881, 'genres': 'Action|Thriller', 'title': 'Double Jeopardy (1999)'}
# {'_id': 2871, 'genres': 'Adventure|Thriller', 'title': 'Deliverance (1972)'}
# {'_id': 2850, 'genres': 'Drama|Thriller', 'title': 'Public Access (1993)'}
# {'_id': 2835, 'genres': 'Action|Thriller', 'title': 'Chill Factor (1999)'}
# {'_id': 2806,
#  'genres': 'Comedy|Thriller',
#  'title': 'Teaching Mrs. Tingle (1999)'}
# {'_id': 2812, 'genres': 'Action|Thriller', 'title': 'In Too Deep (1999)'}
# {'_id': 2741, 'genres': 'Action|Thriller', 'title': 'No Mercy (1986)'}
# {'_id': 2763,
#  'genres': 'Action|Thriller',
#  'title': 'Thomas Crown Affair, The (1999)'}
# {'_id': 2719, 'genres': 'Horror|Thriller', 'title': 'Haunting, The (1999)'}
# {'_id': 2713, 'genres': 'Horror|Thriller', 'title': 'Lake Placid (1999)'}
# {'_id': 2688,
#  'genres': 'Drama|Thriller',
#  'title': "General's Daughter, The (1999)"}
# {'_id': 2676, 'genres': 'Drama|Thriller', 'title': 'Instinct (1999)'}
# {'_id': 2605, 'genres': 'Crime|Thriller', 'title': 'Entrapment (1999)'}
# {'_id': 2550, 'genres': 'Horror|Thriller', 'title': 'Haunting, The (1963)'}
# {'_id': 2561, 'genres': 'Crime|Thriller', 'title': 'True Crime (1999)'}
# {'_id': 2551, 'genres': 'Drama|Thriller', 'title': 'Dead Ringers (1988)'}
# {'_id': 2523, 'genres': 'Drama|Thriller', 'title': 'Rollercoaster (1977)'}
# {'_id': 2490, 'genres': 'Action|Thriller', 'title': 'Payback (1999)'}
# {'_id': 2479, 'genres': 'Drama|Thriller', 'title': 'Gloria (1999)'}
# {'_id': 2438, 'genres': 'Drama|Thriller', 'title': 'Outside Ozona (1998)'}
# {'_id': 2419, 'genres': 'Drama|Thriller', 'title': 'Extremities (1986)'}
# {'_id': 2391, 'genres': 'Crime|Thriller', 'title': 'Simple Plan, A (1998)'}
# {'_id': 2353, 'genres': 'Action|Thriller', 'title': 'Enemy of the State (1998)'}
# {'_id': 2349, 'genres': 'Comedy|Thriller', 'title': 'Mona Lisa (1986)'}
# {'_id': 2334, 'genres': 'Action|Thriller', 'title': 'Siege, The (1998)'}
# {'_id': 2326, 'genres': 'Drama|Thriller', 'title': 'Shattered Image (1998)'}
# {'_id': 2320, 'genres': 'Drama|Thriller', 'title': 'Apt Pupil (1998)'}
# {'_id': 2315, 'genres': 'Horror|Thriller', 'title': 'Bride of Chucky (1998)'}
# {'_id': 2279, 'genres': 'Horror|Thriller', 'title': 'Urban Legend (1998)'}
# {'_id': 2273, 'genres': 'Action|Thriller', 'title': 'Rush Hour (1998)'}
# {'_id': 2267, 'genres': 'Mystery|Thriller', 'title': 'Mortal Thoughts (1991)'}
# {'_id': 2219, 'genres': 'Mystery|Thriller', 'title': 'Murder! (1930)'}
# {'_id': 2209, 'genres': 'Crime|Thriller', 'title': 'Young and Innocent (1937)'}
# {'_id': 2206, 'genres': 'Mystery|Thriller', 'title': 'Suspicion (1941)'}
# {'_id': 2187, 'genres': 'Mystery|Thriller', 'title': 'Stage Fright (1950)'}
# {'_id': 2184,
#  'genres': 'Mystery|Thriller',
#  'title': 'Trouble with Harry, The (1955)'}
# {'_id': 2177, 'genres': 'Comedy|Thriller', 'title': 'Family Plot (1976)'}
# {'_id': 2160, 'genres': 'Horror|Thriller', 'title': "Rosemary's Baby (1968)"}
# {'_id': 2113, 'genres': 'Horror|Thriller', 'title': 'Graveyard Shift (1990)'}
# {'_id': 2118, 'genres': 'Horror|Thriller', 'title': 'Dead Zone, The (1983)'}
# {'_id': 2122,
#  'genres': 'Horror|Thriller',
#  'title': 'Children of the Corn (1984)'}
# {'_id': 2121, 'genres': 'Horror|Thriller', 'title': 'Cujo (1983)'}
# {'_id': 2107, 'genres': 'Horror|Thriller', 'title': 'Halloween: H20 (1998)'}
# {'_id': 2058, 'genres': 'Action|Thriller', 'title': 'Negotiator, The (1998)'}
# {'_id': 2026,
#  'genres': 'Horror|Thriller',
#  'title': 'Disturbing Behavior (1998)'}
# {'_id': 1996, 'genres': 'Horror|Thriller', 'title': 'Poltergeist III (1988)'}
# {'_id': 1995,
#  'genres': 'Horror|Thriller',
#  'title': 'Poltergeist II: The Other Side (1986)'}
# {'_id': 1994, 'genres': 'Horror|Thriller', 'title': 'Poltergeist (1982)'}
# {'_id': 1908, 'genres': 'Drama|Thriller', 'title': 'Resurrection Man (1998)'}
# {'_id': 1892, 'genres': 'Mystery|Thriller', 'title': 'Perfect Murder, A (1998)'}
# {'_id': 1891, 'genres': 'Horror|Thriller', 'title': 'Ugly, The (1997)'}
# {'_id': 1869, 'genres': 'Action|Thriller', 'title': 'Black Dog (1998)'}
# {'_id': 1861, 'genres': 'Comedy|Thriller', 'title': 'Junk Mail (1997)'}
# {'_id': 1852, 'genres': 'Drama|Thriller', 'title': 'Love Walked In (1998)'}
# {'_id': 1847, 'genres': 'Drama|Thriller', 'title': 'Ratchet (1996)'}
# {'_id': 1845, 'genres': 'Comedy|Thriller', 'title': 'Zero Effect (1998)'}
# {'_id': 1841,
#  'genres': 'Drama|Thriller',
#  'title': 'Gingerbread Man, The (1998)'}
# {'_id': 1834,
#  'genres': 'Drama|Thriller',
#  'title': 'Spanish Prisoner, The (1997)'}
# {'_id': 1824, 'genres': 'Comedy|Thriller', 'title': 'Homegrown (1998)'}
# {'_id': 1792, 'genres': 'Action|Thriller', 'title': 'U.S. Marshalls (1998)'}
# {'_id': 1769,
#  'genres': 'Action|Thriller',
#  'title': 'Replacement Killers, The (1998)'}
# {'_id': 1770, 'genres': 'Romance|Thriller', 'title': 'B. Monkey (1998)'}
# {'_id': 1764, 'genres': 'Comedy|Thriller', 'title': 'Tainted (1998)'}
# {'_id': 1752, 'genres': 'Action|Thriller', 'title': 'Hard Rain (1998)'}
# {'_id': 1717, 'genres': 'Horror|Thriller', 'title': 'Scream 2 (1997)'}
# {'_id': 1687, 'genres': 'Action|Thriller', 'title': 'Jackal, The (1997)'}
# {'_id': 1675, 'genres': 'Crime|Thriller', 'title': 'Incognito (1997)'}
# {'_id': 1686, 'genres': 'Crime|Thriller', 'title': 'Red Corner (1997)'}
# {'_id': 1658,
#  'genres': 'Romance|Thriller',
#  'title': 'Life Less Ordinary, A (1997)'}
# {'_id': 1608, 'genres': 'Action|Thriller', 'title': 'Air Force One (1997)'}
# {'_id': 1615, 'genres': 'Adventure|Thriller', 'title': 'Edge, The (1997)'}
# {'_id': 1647, 'genres': 'Crime|Thriller', 'title': 'Playing God (1997)'}
# {'_id': 1636, 'genres': 'Action|Thriller', 'title': 'Stag (1997)'}
# {'_id': 1625, 'genres': 'Mystery|Thriller', 'title': 'Game, The (1997)'}
# {'_id': 1610,
#  'genres': 'Action|Thriller',
#  'title': 'Hunt for Red October, The (1990)'}
# {'_id': 1565, 'genres': 'Comedy|Thriller', 'title': 'Head Above Water (1996)'}
# {'_id': 1515, 'genres': 'Drama|Thriller', 'title': 'Volcano (1997)'}
# {'_id': 1518, 'genres': 'Action|Thriller', 'title': 'Breakdown (1997)'}
# {'_id': 1483, 'genres': 'Drama|Thriller', 'title': 'Crash (1996)'}
# {'_id': 1472, 'genres': 'Crime|Thriller', 'title': 'City of Industry (1997)'}
# {'_id': 1459, 'genres': 'Mystery|Thriller', 'title': 'Absolute Power (1997)'}
# {'_id': 1438, 'genres': 'Action|Thriller', 'title': "Dante's Peak (1997)"}
# {'_id': 1422, 'genres': 'Mystery|Thriller', 'title': 'Murder at 1600 (1997)'}
# {'_id': 1407, 'genres': 'Horror|Thriller', 'title': 'Scream (1996)'}
# {'_id': 1355, 'genres': 'Horror|Thriller', 'title': 'Nightwatch (1997)'}
# {'_id': 1352, 'genres': 'Crime|Thriller', 'title': 'Albino Alligator (1996)'}
# {'_id': 1370, 'genres': 'Action|Thriller', 'title': 'Die Hard 2 (1990)'}
# {'_id': 1369,
#  'genres': 'Drama|Thriller',
#  'title': "I Can't Sleep (J'ai pas sommeil) (1994)"}
# {'_id': 1358, 'genres': 'Drama|Thriller', 'title': 'Sling Blade (1996)'}
# {'_id': 1332, 'genres': 'Horror|Thriller', 'title': 'Believers, The (1987)'}
# {'_id': 1218,
#  'genres': 'Action|Thriller',
#  'title': 'Killer, The (Die xue shuang xiong) (1989)'}
# {'_id': 1219, 'genres': 'Horror|Thriller', 'title': 'Psycho (1960)'}
# {'_id': 1212, 'genres': 'Mystery|Thriller', 'title': 'Third Man, The (1949)'}
# {'_id': 1165, 'genres': 'Drama|Thriller', 'title': 'Bloody Child, The (1996)'}
# {'_id': 1092, 'genres': 'Mystery|Thriller', 'title': 'Basic Instinct (1992)'}
# {'_id': 1089, 'genres': 'Crime|Thriller', 'title': 'Reservoir Dogs (1992)'}
# {'_id': 1086, 'genres': 'Mystery|Thriller', 'title': 'Dial M for Murder (1954)'}
# {'_id': 1047,
#  'genres': 'Action|Thriller',
#  'title': 'Long Kiss Goodnight, The (1996)'}
# {'_id': 1036, 'genres': 'Action|Thriller', 'title': 'Die Hard (1988)'}
# {'_id': 997, 'genres': 'Drama|Thriller', 'title': 'Caught (1996)'}
# {'_id': 1004, 'genres': 'Action|Thriller', 'title': 'Glimmer Man, The (1996)'}
# {'_id': 1003, 'genres': 'Drama|Thriller', 'title': 'Extreme Measures (1996)'}
# {'_id': 928, 'genres': 'Romance|Thriller', 'title': 'Rebecca (1940)'}
# {'_id': 908, 'genres': 'Drama|Thriller', 'title': 'North by Northwest (1959)'}
# {'_id': 906, 'genres': 'Mystery|Thriller', 'title': 'Gaslight (1944)'}
# {'_id': 904, 'genres': 'Mystery|Thriller', 'title': 'Rear Window (1954)'}
# {'_id': 903, 'genres': 'Mystery|Thriller', 'title': 'Vertigo (1958)'}
# {'_id': 891,
#  'genres': 'Horror|Thriller',
#  'title': 'Halloween: The Curse of Michael Myers (1995)'}
# {'_id': 882, 'genres': 'Drama|Thriller', 'title': 'Trigger Effect, The (1996)'}
# {'_id': 861, 'genres': 'Action|Thriller', 'title': 'Supercop (1992)'}
# {'_id': 839,
#  'genres': 'Action|Thriller',
#  'title': 'Crow: City of Angels, The (1996)'}
# {'_id': 832, 'genres': 'Drama|Thriller', 'title': 'Ransom (1996)'}
# {'_id': 786, 'genres': 'Action|Thriller', 'title': 'Eraser (1996)'}
# {'_id': 742, 'genres': 'Horror|Thriller', 'title': 'Thinner (1996)'}
# {'_id': 731, 'genres': 'Mystery|Thriller', 'title': "Heaven's Prisoners (1996)"}
# {'_id': 640, 'genres': 'Drama|Thriller', 'title': 'Diabolique (1996)'}
# {'_id': 695, 'genres': 'Mystery|Thriller', 'title': 'True Crime (1995)'}
# {'_id': 678,
#  'genres': 'Drama|Thriller',
#  'title': 'Some Folks Call It a Sling Blade (1993)'}
# {'_id': 659, 'genres': 'Crime|Thriller', 'title': 'Purple Noon (1960)'}
# {'_id': 627, 'genres': 'Drama|Thriller', 'title': 'Last Supper, The (1995)'}
# {'_id': 628, 'genres': 'Drama|Thriller', 'title': 'Primal Fear (1996)'}
# {'_id': 614, 'genres': 'Drama|Thriller', 'title': 'Loaded (1994)'}
# {'_id': 593,
#  'genres': 'Drama|Thriller',
#  'title': 'Silence of the Lambs, The (1991)'}
# {'_id': 521, 'genres': 'Crime|Thriller', 'title': 'Romeo Is Bleeding (1993)'}
# {'_id': 481, 'genres': 'Drama|Thriller', 'title': 'Kalifornia (1993)'}
# {'_id': 494, 'genres': 'Action|Thriller', 'title': 'Executive Decision (1996)'}
# {'_id': 474, 'genres': 'Action|Thriller', 'title': 'In the Line of Fire (1993)'}
# {'_id': 454, 'genres': 'Drama|Thriller', 'title': 'Firm, The (1993)'}
# {'_id': 457, 'genres': 'Action|Thriller', 'title': 'Fugitive, The (1993)'}
# {'_id': 436, 'genres': 'Drama|Thriller', 'title': 'Color of Night (1994)'}
# {'_id': 423, 'genres': 'Action|Thriller', 'title': 'Blown Away (1994)'}
# {'_id': 415, 'genres': 'Comedy|Thriller', 'title': 'Another Stakeout (1993)'}
# {'_id': 407,
#  'genres': 'Horror|Thriller',
#  'title': 'In the Mouth of Madness (1995)'}
# {'_id': 401, 'genres': 'Action|Thriller', 'title': 'Mirage (1995)'}
# {'_id': 376, 'genres': 'Action|Thriller', 'title': 'River Wild, The (1994)'}
# {'_id': 335, 'genres': 'Mystery|Thriller', 'title': 'Underneath, The (1995)'}
# {'_id': 311, 'genres': 'Horror|Thriller', 'title': 'Relative Fear (1994)'}
# {'_id': 288,
#  'genres': 'Action|Thriller',
#  'title': 'Natural Born Killers (1994)'}
# {'_id': 280, 'genres': 'Drama|Thriller', 'title': 'Murder in the First (1995)'}
# {'_id': 257, 'genres': 'Mystery|Thriller', 'title': 'Just Cause (1995)'}
# {'_id': 230, 'genres': 'Drama|Thriller', 'title': 'Dolores Claiborne (1994)'}
# {'_id': 229, 'genres': 'Drama|Thriller', 'title': 'Death and the Maiden (1994)'}
# {'_id': 225, 'genres': 'Drama|Thriller', 'title': 'Disclosure (1994)'}
# {'_id': 217, 'genres': 'Drama|Thriller', 'title': 'Babysitter, The (1995)'}
# {'_id': 165,
#  'genres': 'Action|Thriller',
#  'title': 'Die Hard: With a Vengeance (1995)'}
# {'_id': 111, 'genres': 'Drama|Thriller', 'title': 'Taxi Driver (1976)'}
# {'_id': 95, 'genres': 'Action|Thriller', 'title': 'Broken Arrow (1996)'}
# {'_id': 100, 'genres': 'Drama|Thriller', 'title': 'City Hall (1996)'}
# {'_id': 98, 'genres': 'Action|Thriller', 'title': 'Shopping (1994)'}
# {'_id': 92, 'genres': 'Drama|Thriller', 'title': 'Mary Reilly (1996)'}
# {'_id': 89, 'genres': 'Action|Thriller', 'title': 'Nick of Time (1995)'}
# {'_id': 79, 'genres': 'Drama|Thriller', 'title': 'Juror, The (1996)'}
# {'_id': 61, 'genres': 'Drama|Thriller', 'title': 'Eye for an Eye (1996)'}
# {'_id': 50, 'genres': 'Crime|Thriller', 'title': 'Usual Suspects, The (1995)'}
# {'_id': 47, 'genres': 'Crime|Thriller', 'title': 'Seven (Se7en) (1995)'}
# {'_id': 16, 'genres': 'Drama|Thriller', 'title': 'Casino (1995)'}
# {'_id': 3946, 'genres': 'Action|Drama|Thriller', 'title': 'Get Carter (2000)'}
# {'_id': 3830,
#  'genres': 'Comedy|Horror|Thriller',
#  'title': 'Psycho Beach Party (2000)'}
# {'_id': 3764, 'genres': 'Action|Crime|Thriller', 'title': 'F/X 2 (1992)'}
# {'_id': 3763, 'genres': 'Action|Crime|Thriller', 'title': 'F/X (1986)'}
# {'_id': 3755,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Perfect Storm, The (2000)'}
# {'_id': 3535,
#  'genres': 'Comedy|Horror|Thriller',
#  'title': 'American Psycho (2000)'}
# {'_id': 3476,
#  'genres': 'Horror|Mystery|Thriller',
#  'title': "Jacob's Ladder (1990)"}
# {'_id': 3461,
#  'genres': 'Adventure|Drama|Thriller',
#  'title': 'Lord of the Flies (1963)'}
# {'_id': 3443,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Born American (1986)'}
# {'_id': 3273, 'genres': 'Horror|Mystery|Thriller', 'title': 'Scream 3 (2000)'}
# {'_id': 3227,
#  'genres': 'Comedy|Drama|Thriller',
#  'title': 'Not Love, Just Frenzy (M�s que amor, frenes�) (1996)'}
# {'_id': 3176,
#  'genres': 'Drama|Mystery|Thriller',
#  'title': 'Talented Mr. Ripley, The (1999)'}
# {'_id': 3044,
#  'genres': 'Mystery|Romance|Thriller',
#  'title': 'Dead Again (1991)'}
# {'_id': 2956,
#  'genres': 'Action|Crime|Thriller',
#  'title': 'Someone to Watch Over Me (1987)'}
# {'_id': 2826,
#  'genres': 'Action|Horror|Thriller',
#  'title': '13th Warrior, The (1999)'}
# {'_id': 2802,
#  'genres': 'Action|Romance|Thriller',
#  'title': 'Tequila Sunrise (1988)'}
# {'_id': 2764,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Thomas Crown Affair, The (1968)'}
# {'_id': 2586,
#  'genres': 'Comedy|Crime|Thriller',
#  'title': 'Goodbye, Lover (1999)'}
# {'_id': 2542,
#  'genres': 'Comedy|Crime|Thriller',
#  'title': 'Lock, Stock & Two Smoking Barrels (1998)'}
# {'_id': 2488, 'genres': 'Drama|Horror|Thriller', 'title': 'Peeping Tom (1960)'}
# {'_id': 2483,
#  'genres': 'Comedy|Horror|Thriller',
#  'title': 'Day of the Beast, The (El D�a de la bestia) (1995)'}
# {'_id': 2475, 'genres': 'Action|Mystery|Thriller', 'title': '52 Pick-Up (1986)'}
# {'_id': 2389, 'genres': 'Crime|Horror|Thriller', 'title': 'Psycho (1998)'}
# {'_id': 2338,
#  'genres': 'Horror|Mystery|Thriller',
#  'title': 'I Still Know What You Did Last Summer (1998)'}
# {'_id': 2278, 'genres': 'Action|Crime|Thriller', 'title': 'Ronin (1998)'}
# {'_id': 2202, 'genres': 'Drama|Thriller|War', 'title': 'Lifeboat (1944)'}
# {'_id': 2203,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Shadow of a Doubt (1943)'}
# {'_id': 2186,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Strangers on a Train (1951)'}
# {'_id': 2110,
#  'genres': 'Comedy|Crime|Thriller',
#  'title': "Dead Men Don't Wear Plaid (1982)"}
# {'_id': 1833,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Mercury Rising (1998)'}
# {'_id': 1754, 'genres': 'Action|Mystery|Thriller', 'title': 'Fallen (1998)'}
# {'_id': 1744,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Firestorm (1998)'}
# {'_id': 1722,
#  'genres': 'Action|Romance|Thriller',
#  'title': 'Tomorrow Never Dies (1997)'}
# {'_id': 1674, 'genres': 'Drama|Romance|Thriller', 'title': 'Witness (1985)'}
# {'_id': 1683,
#  'genres': 'Drama|Romance|Thriller',
#  'title': 'Wings of the Dove, The (1997)'}
# {'_id': 1648,
#  'genres': 'Comedy|Drama|Thriller',
#  'title': 'House of Yes, The (1997)'}
# {'_id': 1644,
#  'genres': 'Horror|Mystery|Thriller',
#  'title': 'I Know What You Did Last Summer (1997)'}
# {'_id': 1616,
#  'genres': 'Action|Thriller|War',
#  'title': 'Peacemaker, The (1997)'}
# {'_id': 1626,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Fire Down Below (1997)'}
# {'_id': 1620,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Kiss the Girls (1997)'}
# {'_id': 1598,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Desperate Measures (1998)'}
# {'_id': 1556,
#  'genres': 'Action|Romance|Thriller',
#  'title': 'Speed 2: Cruise Control (1997)'}
# {'_id': 1552, 'genres': 'Action|Adventure|Thriller', 'title': 'Con Air (1997)'}
# {'_id': 1499, 'genres': 'Action|Adventure|Thriller', 'title': 'Anaconda (1997)'}
# {'_id': 1479, 'genres': 'Action|Romance|Thriller', 'title': 'Saint, The (1997)'}
# {'_id': 1480,
#  'genres': 'Action|Drama|Thriller',
#  'title': "Smilla's Sense of Snow (1997)"}
# {'_id': 1344, 'genres': 'Film-Noir|Thriller', 'title': 'Cape Fear (1962)'}
# {'_id': 1267,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Manchurian Candidate, The (1962)'}
# {'_id': 1269,
#  'genres': 'Comedy|Mystery|Thriller',
#  'title': 'Arsenic and Old Lace (1944)'}
# {'_id': 1227,
#  'genres': 'Crime|Drama|Thriller',
#  'title': 'Once Upon a Time in America (1984)'}
# {'_id': 1151, 'genres': 'Animation|Comedy|Thriller', 'title': 'Faust (1994)'}
# {'_id': 1069,
#  'genres': 'Film-Noir|Thriller',
#  'title': 'Murder, My Sweet (1944)'}
# {'_id': 990,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Maximum Risk (1996)'}
# {'_id': 933,
#  'genres': 'Comedy|Romance|Thriller',
#  'title': 'To Catch a Thief (1955)'}
# {'_id': 931, 'genres': 'Mystery|Romance|Thriller', 'title': 'Spellbound (1945)'}
# {'_id': 836,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Chain Reaction (1996)'}
# {'_id': 815, 'genres': 'Action|Mystery|Thriller', 'title': 'Power 98 (1995)'}
# {'_id': 798, 'genres': 'Action|Adventure|Thriller', 'title': 'Daylight (1996)'}
# {'_id': 733, 'genres': 'Action|Adventure|Thriller', 'title': 'Rock, The (1996)'}
# {'_id': 745,
#  'genres': 'Animation|Comedy|Thriller',
#  'title': 'Close Shave, A (1995)'}
# {'_id': 675,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Hostile Intentions (1994)'}
# {'_id': 624, 'genres': 'Action|Drama|Thriller', 'title': 'Condition Red (1995)'}
# {'_id': 591,
#  'genres': 'Action|Drama|Thriller',
#  'title': 'Tough and Deadly (1995)'}
# {'_id': 608, 'genres': 'Crime|Drama|Thriller', 'title': 'Fargo (1996)'}
# {'_id': 587, 'genres': 'Comedy|Romance|Thriller', 'title': 'Ghost (1990)'}
# {'_id': 543,
#  'genres': 'Comedy|Romance|Thriller',
#  'title': 'So I Married an Axe Murderer (1993)'}
# {'_id': 547,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Surviving the Game (1994)'}
# {'_id': 463, 'genres': 'Crime|Drama|Thriller', 'title': 'Guilty as Sin (1993)'}
# {'_id': 427,
#  'genres': 'Mystery|Romance|Thriller',
#  'title': 'Boxing Helena (1993)'}
# {'_id': 377, 'genres': 'Action|Romance|Thriller', 'title': 'Speed (1994)'}
# {'_id': 353, 'genres': 'Action|Romance|Thriller', 'title': 'Crow, The (1994)'}
# {'_id': 349,
#  'genres': 'Action|Adventure|Thriller',
#  'title': 'Clear and Present Danger (1994)'}
# {'_id': 350, 'genres': 'Drama|Mystery|Thriller', 'title': 'Client, The (1994)'}
# {'_id': 320, 'genres': 'Film-Noir|Thriller', 'title': 'Suture (1993)'}
# {'_id': 292, 'genres': 'Action|Drama|Thriller', 'title': 'Outbreak (1995)'}
# {'_id': 259, 'genres': 'Crime|Drama|Thriller', 'title': 'Kiss of Death (1995)'}
# {'_id': 163, 'genres': 'Action|Romance|Thriller', 'title': 'Desperado (1995)'}
# {'_id': 170, 'genres': 'Action|Crime|Thriller', 'title': 'Hackers (1995)'}
# {'_id': 161, 'genres': 'Drama|Thriller|War', 'title': 'Crimson Tide (1995)'}
# {'_id': 149, 'genres': 'Crime|Drama|Thriller', 'title': 'Amateur (1994)'}
# {'_id': 51, 'genres': 'Action|Drama|Thriller', 'title': 'Guardian Angel (1994)'}
# {'_id': 10, 'genres': 'Action|Adventure|Thriller', 'title': 'GoldenEye (1995)'}
# {'_id': 6, 'genres': 'Action|Crime|Thriller', 'title': 'Heat (1995)'}
# {'_id': 22, 'genres': 'Crime|Drama|Thriller', 'title': 'Copycat (1995)'}
# {'_id': 3706,
#  'genres': 'Film-Noir|Mystery|Thriller',
#  'title': 'Angel Heart (1987)'}
# {'_id': 3705,
#  'genres': 'Action|Adventure|Romance|Thriller',
#  'title': 'Bird on a Wire (1990)'}
# {'_id': 3584,
#  'genres': 'Action|Drama|Romance|Thriller',
#  'title': 'Breathless (1983)'}
# {'_id': 3257,
#  'genres': 'Action|Drama|Romance|Thriller',
#  'title': 'Bodyguard, The (1992)'}
# {'_id': 2631,
#  'genres': 'Comedy|Film-Noir|Thriller',
#  'title': 'Frogs for Snakes (1998)'}
# {'_id': 2617,
#  'genres': 'Action|Adventure|Horror|Thriller',
#  'title': 'Mummy, The (1999)'}
# {'_id': 2540,
#  'genres': 'Action|Crime|Drama|Thriller',
#  'title': 'Corruptor, The (1999)'}
# {'_id': 2468,
#  'genres': 'Action|Comedy|Romance|Thriller',
#  'title': "Jumpin' Jack Flash (1986)"}
# {'_id': 2344,
#  'genres': 'Action|Adventure|Drama|Thriller',
#  'title': 'Runaway Train (1985)'}
# {'_id': 2208,
#  'genres': 'Comedy|Mystery|Romance|Thriller',
#  'title': 'Lady Vanishes, The (1938)'}
# {'_id': 2182,
#  'genres': 'Drama|Film-Noir|Thriller',
#  'title': 'Wrong Man, The (1956)'}
# {'_id': 2126,
#  'genres': 'Action|Crime|Mystery|Thriller',
#  'title': 'Snake Eyes (1998)'}
# {'_id': 1953,
#  'genres': 'Action|Crime|Drama|Thriller',
#  'title': 'French Connection, The (1971)'}
# {'_id': 1805,
#  'genres': 'Crime|Drama|Mystery|Thriller',
#  'title': 'Wild Things (1998)'}
# {'_id': 1783,
#  'genres': 'Film-Noir|Mystery|Thriller',
#  'title': 'Palmetto (1998)'}
# {'_id': 1732,
#  'genres': 'Comedy|Crime|Mystery|Thriller',
#  'title': 'Big Lebowski, The (1998)'}
# {'_id': 1645,
#  'genres': 'Crime|Horror|Mystery|Thriller',
#  'title': "Devil's Advocate, The (1997)"}
# {'_id': 1597,
#  'genres': 'Action|Mystery|Romance|Thriller',
#  'title': 'Conspiracy Theory (1997)'}
# {'_id': 1488,
#  'genres': 'Action|Drama|Thriller|War',
#  'title': "Devil's Own, The (1997)"}
# {'_id': 1260, 'genres': 'Crime|Film-Noir|Thriller', 'title': 'M (1931)'}
# {'_id': 1252,
#  'genres': 'Film-Noir|Mystery|Thriller',
#  'title': 'Chinatown (1974)'}
# {'_id': 1248,
#  'genres': 'Crime|Film-Noir|Thriller',
#  'title': 'Touch of Evil (1958)'}
# {'_id': 1152,
#  'genres': 'Crime|Film-Noir|Thriller',
#  'title': 'He Walked by Night (1948)'}
# {'_id': 930,
#  'genres': 'Film-Noir|Romance|Thriller',
#  'title': 'Notorious (1946)'}
# {'_id': 911,
#  'genres': 'Comedy|Mystery|Romance|Thriller',
#  'title': 'Charade (1963)'}
# {'_id': 866, 'genres': 'Crime|Drama|Romance|Thriller', 'title': 'Bound (1996)'}
# {'_id': 736,
#  'genres': 'Action|Adventure|Romance|Thriller',
#  'title': 'Twister (1996)'}
# {'_id': 707,
#  'genres': 'Crime|Film-Noir|Thriller',
#  'title': 'Mulholland Falls (1996)'}
# {'_id': 464,
#  'genres': 'Action|Adventure|Crime|Thriller',
#  'title': 'Hard Target (1993)'}
# {'_id': 293,
#  'genres': 'Crime|Drama|Romance|Thriller',
#  'title': 'Professional, The (a.k.a. Leon: The Professional) (1994)'}
# {'_id': 247,
#  'genres': 'Drama|Fantasy|Romance|Thriller',
#  'title': 'Heavenly Creatures (1994)'}
# {'_id': 3334,
#  'genres': 'Crime|Drama|Film-Noir|Thriller',
#  'title': 'Key Largo (1948)'}
# {'_id': 1617,
#  'genres': 'Crime|Film-Noir|Mystery|Thriller',
#  'title': 'L.A. Confidential (1997)'}
# {'_id': 1264,
#  'genres': 'Action|Drama|Mystery|Romance|Thriller',
#  'title': 'Diva (1981)'}
# {'_id': 164,
#  'genres': 'Crime|Film-Noir|Mystery|Thriller',
#  'title': 'Devil in a Blue Dress (1995)'}
# {'_id': 70,
#  'genres': 'Action|Comedy|Crime|Horror|Thriller',
#  'title': 'From Dusk Till Dawn (1996)'}

# %% [markdown]
# **Q**: Display the first 30 movies (`limit`) in alphabetical order (`sort`) by title

# %%
first_30_movies = movies.find().sort("title").limit(30)

for movie in first_30_movies:
    pprint(movie)
# Out:
# {'_id': 2031, 'genres': "Children's|Comedy", 'title': '$1,000,000 Duck (1971)'}
# {'_id': 3112, 'genres': 'Drama', 'title': "'Night Mother (1986)"}
# {'_id': 779, 'genres': 'Drama|Romance', 'title': "'Til There Was You (1997)"}
# {'_id': 2072, 'genres': 'Comedy', 'title': "'burbs, The (1989)"}
# {'_id': 3420,
#  'genres': 'Drama|Thriller',
#  'title': '...And Justice for All (1979)'}
# {'_id': 889, 'genres': 'Romance', 'title': '1-900 (1994)'}
# {'_id': 2572,
#  'genres': 'Comedy|Romance',
#  'title': '10 Things I Hate About You (1999)'}
# {'_id': 2085,
#  'genres': "Animation|Children's",
#  'title': '101 Dalmatians (1961)'}
# {'_id': 1367, 'genres': "Children's|Comedy", 'title': '101 Dalmatians (1996)'}
# {'_id': 1203, 'genres': 'Drama', 'title': '12 Angry Men (1957)'}
# {'_id': 2826,
#  'genres': 'Action|Horror|Thriller',
#  'title': '13th Warrior, The (1999)'}
# {'_id': 1609, 'genres': 'Drama', 'title': '187 (1997)'}
# {'_id': 999, 'genres': 'Crime', 'title': '2 Days in the Valley (1996)'}
# {'_id': 2492, 'genres': 'Comedy', 'title': '20 Dates (1998)'}
# {'_id': 1019,
#  'genres': "Adventure|Children's|Fantasy|Sci-Fi",
#  'title': '20,000 Leagues Under the Sea (1954)'}
# {'_id': 2504, 'genres': 'Comedy|Drama', 'title': '200 Cigarettes (1999)'}
# {'_id': 924,
#  'genres': 'Drama|Mystery|Sci-Fi|Thriller',
#  'title': '2001: A Space Odyssey (1968)'}
# {'_id': 2311, 'genres': 'Mystery|Sci-Fi', 'title': '2010 (1984)'}
# {'_id': 2444,
#  'genres': 'Comedy|Drama',
#  'title': '24 7: Twenty Four Seven (1997)'}
# {'_id': 2486, 'genres': 'Drama', 'title': '24-hour Woman (1998)'}
# {'_id': 3534, 'genres': 'Comedy', 'title': '28 Days (2000)'}
# {'_id': 1739,
#  'genres': "Action|Children's",
#  'title': '3 Ninjas: High Noon On Mega Mountain (1998)'}
# {'_id': 3322, 'genres': 'Comedy', 'title': '3 Strikes (2000)'}
# {'_id': 652, 'genres': 'Mystery', 'title': '301, 302 (1995)'}
# {'_id': 965, 'genres': 'Thriller', 'title': '39 Steps, The (1935)'}
# {'_id': 2731,
#  'genres': 'Drama',
#  'title': '400 Blows, The (Les Quatre cents coups) (1959)'}
# {'_id': 3077, 'genres': 'Documentary', 'title': '42 Up (1998)'}
# {'_id': 2475, 'genres': 'Action|Mystery|Thriller', 'title': '52 Pick-Up (1986)'}
# {'_id': 2188, 'genres': 'Drama', 'title': '54 (1998)'}
# {'_id': 3153,
#  'genres': 'Action|Adventure|Fantasy',
#  'title': '7th Voyage of Sinbad, The (1958)'}

# %% [markdown]
# **Q**: How many users have seen the movie "Star Wars: Episode V - The Empire Strikes Back (1980)" (`_id 1196`) ? The `movies` argument is an array so we should try the [elemMatch](https://docs.mongodb.com/manual/reference/operator/projection/elemMatch/) operator here.

# %%
movies.find({'_id' : 1196})[0]
# Out:
# {'_id': 1196,
#  'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  'genres': 'Action|Adventure|Drama|Sci-Fi|War'}

# %%
users.count_documents({
    "movies" : {
        "$elemMatch" : {
            "movieid" : { "$eq" : 1196}
        }
    }
})
# Out:
# 2990

# %%
users.find_one()
# Out:
# {'_id': 6038,
#  'name': 'Yaeko Hassan',
#  'gender': 'F',
#  'age': 95,
#  'occupation': 'academic/educator',
#  'movies': [{'movieid': 1419, 'rating': 4, 'timestamp': 956714815},
#   {'movieid': 920, 'rating': 3, 'timestamp': 956706827},
#   {'movieid': 3088, 'rating': 5, 'timestamp': 956707640},
#   {'movieid': 232, 'rating': 4, 'timestamp': 956707640},
#   {'movieid': 1136, 'rating': 4, 'timestamp': 956707708},
#   {'movieid': 1148, 'rating': 5, 'timestamp': 956707604},
#   {'movieid': 1183, 'rating': 5, 'timestamp': 956717204},
#   {'movieid': 2146, 'rating': 4, 'timestamp': 956706909},
#   {'movieid': 3548, 'rating': 4, 'timestamp': 956707604},
#   {'movieid': 356, 'rating': 4, 'timestamp': 956707005},
#   {'movieid': 1210, 'rating': 4, 'timestamp': 956706876},
#   {'movieid': 1223, 'rating': 5, 'timestamp': 956707734},
#   {'movieid': 1276, 'rating': 3, 'timestamp': 956707604},
#   {'movieid': 1296, 'rating': 5, 'timestamp': 956714684},
#   {'movieid': 1354, 'rating': 3, 'timestamp': 956714725},
#   {'movieid': 1387, 'rating': 2, 'timestamp': 956707005},
#   {'movieid': 2700, 'rating': 1, 'timestamp': 956715051},
#   {'movieid': 2716, 'rating': 3, 'timestamp': 956707604},
#   {'movieid': 3396, 'rating': 3, 'timestamp': 956706827},
#   {'movieid': 1079, 'rating': 5, 'timestamp': 956707547}]}

# %% [markdown]
# **Q**: And how many gave it a rating of 1 or 2 ?

# %%
users.count_documents({
    "movies" : {
        "$elemMatch" : {
            "movieid" : { "$eq" : 1196},
            "$or" : [ { "rating" : {"$eq" : 1} }, { "rating" : {"$eq" : 2} }]
        }
    }
})
# Out:
# 105

# %% [markdown]
# ### Updating data

# %% [markdown]
# **Q**: Insert a new user with the properties `name`, `gender` ('M' or'F'), `occupation` and `age`, using the `insert_one()` command. Display it with `find_one()`.

# %%
user = {
    "name" : "Ndeye-Fatou Dieng",
    "gender" : 'F',
    "occupation" : "data scientist",
    "age" : 23
}
users.insert_one(user)
# Out:
# InsertOneResult(ObjectId('65ae760a65925e6c68a9568d'), acknowledged=True)

# %%
users.find_one({'name' : 'Ndeye-Fatou Dieng'})
# Out:
# {'_id': ObjectId('65ae760a65925e6c68a9568d'),
#  'name': 'Ndeye-Fatou Dieng',
#  'gender': 'F',
#  'occupation': 'data scientist',
#  'age': 23}

# %% [markdown]
# **Q**: Add an appreciation on a viewed movie with `update_one()`, add the movies property containing a table with a document (`movieid`, `rating`, `timestamp` with the value `datetime.datetime.utcnow()`).
#
# You will need to read the documentation on [update operators](https://docs.mongodb.org/manual/reference/operator/update/).

# %%
newMovie = {
    'movieid': 3088, 
    'rating': 5, 
    'timestamp': datetime.datetime.utcnow()
}

# %%
users.update_one({'name' : 'Ndeye-Fatou Dieng'}, {"$set": { "movies": newMovie } })
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# **Q**: Find the number of users who have declared a `programmer` occupation. Modify them so that they are `developer`. Verify your update.

# %%
nb_programmers = users.count_documents({
    "occupation" : "programmer"
})
print(f"Nombre de programmeur : {nb_programmers}")
# Out:
# Nombre de programmeur : 388

# %%
users.update_many({
    "occupation" : "programmer"
}, {
    "$set": { "occupation": "developer" } })
# Out:
# UpdateResult({'n': 388, 'nModified': 388, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# ## II. Modelling a blog
#
# We will now model a blog using Mongo.
#
# First, switch to a new `Blog` database. Each blog post will have the following arguments:
#
# * The author (author field, string type)
# * The date (date field, string type in YYYY-MM-DD format)
# * The content (field content)
# * Tags (field tags, a string array)
# * A list of comments (field comments) containing:
#  * The author (author field, string type)
#  * The date (date field, string type in YYYY-MM-DD format)
#  * The content (field content)

# %%
db = client.Blog
posts = db['posts']
comments = db['comments']

# %% [markdown]
# **Q**: Create a first post by `rick`, on January 15th, with the tags `mongodb` and `nosql`.

# %%
post = {
    "author" : "rick",
    "date" : "2024-01-15",
    "content" : "",
    "tags" : "mongodb nosql",
    "commments" : {
        "author" : "",
        "date" : "",
        "content" : ""
    }
}

posts.insert_one(post)
# Out:
# InsertOneResult(ObjectId('65ae802b65925e6c68a9568e'), acknowledged=True)

# %% [markdown]
# **Q**: Create a second post by `kate`, on January 21, with the tag `nosql` and a comment from `rick` on the same day.

# %%
post = {
    "author" : "kate",
    "date" : "2024-01-21",
    "content" : "Hello everybody I'm Kate",
    "tags" : "nosql",
    "commments" : {
        "author" : "rick",
        "date" : "2024-01-21",
        "content" : "Amazing"
    }
}

posts.insert_one(post)
# Out:
# InsertOneResult(ObjectId('65ae807365925e6c68a9568f'), acknowledged=True)

# %% [markdown]
# **Q**: Display the author of the last post with the tag `nosql`

# %%
posts.find({"tags" : "nosql"})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7620\787029696.py in <module>
# ----> 1 posts.find({"tags" : "nosql"})[1]
#
# ~\.conda\envs\nosql\lib\site-packages\pymongo\cursor.py in __getitem__(self, index)
#     767             for doc in clone:
#     768                 return doc
# --> 769             raise IndexError("no such item for Cursor instance")
#     770         raise TypeError("index %r cannot be applied to Cursor instances" % index)
#     771
#
# IndexError: no such item for Cursor instance

# %% [markdown]
# **Q**: Add a comment by `jack` on January 25, to `kate`'s post

# %% [markdown]
# **Q**: Display all comments by `kate`

# %% [markdown]
# ## Postquisites

# %%
# !mongo test_database --eval 'db.dropDatabase()'

# %%
# !mongo MovieLens --eval 'db.dropDatabase()'

# %%
# !mongo Blog --eval 'db.dropDatabase()'
